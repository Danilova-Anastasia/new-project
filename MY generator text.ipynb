# %%
import re
from random import choice
from collections import defaultdict

r_alphabet = re.compile(u'[а-яА-Я0-9-]+')

# %%
def gen_lines(corpus):
    data = open(corpus)
    for line in data:
        yield line.lower()

def gen_tokens(lines):
    for line in lines:
        for token in r_alphabet.findall(line):
            yield token

def gen_trigrams(tokens):
    t0, t1 = next(tokens), next(tokens)
    for t2 in tokens:
        yield t0, t1, t2
        t0, t1 = t1, t2

def fit(corpus):
    lines = gen_lines(corpus)
    tokens = gen_tokens(lines)
    trigrams = gen_trigrams(tokens)

    bi, tri = defaultdict(lambda: 0.0), defaultdict(lambda: 0.0)

    for t0, t1, t2 in trigrams:
        bi[t0, t1] += 1
        tri[t0, t1, t2] += 1

    model = {}
    for (t0, t1, t2), freq in tri.items():
        if (t0, t1) in model:
            model[t0, t1].append((t2, freq/bi[t0, t1]))
        else:
            model[t0, t1] = [(t2, freq/bi[t0, t1])]
    return model

def generate(model, lenght, prefix=-1):
    phrase = ''
    bigrams = tuple(filter(lambda key: key[0] == prefix, model))
    if prefix != -1 and len(bigrams) != 0:
        t0, t1 = choice(tuple(filter(lambda key: key[0] == prefix, model)))
    else:
        t0, t1 = choice(tuple(model))
    phrase += t0
    for i in range(lenght-1):
        phrase += ' ' + t1
        t0, t1 = t1, choice(model[t0, t1])[0]
    return phrase.capitalize()

# %%
if __name__ == '__main__':
    model = fit('Disgardium_5.txt')
    print(generate(model=model, lenght=50, prefix='ты'))
# Out:
# Ты определился с кем имеют дело одноклассники учителя сокурсники из местного колледжа и университета коллеги все идиоты-бывшие чьи имена ей даже писать было противно завистливые соседи все они были из серии слава герою желаете обнародовать свое имя в черную тетрадь и жалела только о левел апах питомцев но и ту

# %%
model
# Out:
# {('дисгардиум', '5'): [('священная', 0.6666666666666666),
#   ('под', 0.3333333333333333)],
#  ('5', 'священная'): [('война', 1.0)],
#  ('священная', 'война'): [('данияр', 0.2),
#   ('краткое', 0.2),
#   ('официально', 0.2),
#   ('начата', 0.2),
#   ('закончена', 0.2)],
#  ('война', 'данияр'): [('саматович', 1.0)],
#  ('данияр', 'саматович'): [('сугралинов', 1.0)],
#  ('саматович', 'сугралинов'): [('дисгардиум', 1.0)],
#  ('сугралинов', 'дисгардиум'): [('5', 1.0)],
#  ('5', 'под'): [('защитой', 1.0)],
#  ('под', 'защитой'): [('нергала', 0.5), ('краша', 0.5)],
#  ('защитой', 'нергала'): [('лучезарного', 1.0)],
#  ('нергала', 'лучезарного'): [('армии', 0.14285714285714285),
#   ('личность', 0.14285714285714285),
#   ('который', 0.14285714285714285),
#   ('во', 0.14285714285714285),
#   ('уже', 0.14285714285714285),
#   ('воздух', 0.14285714285714285),
#   ('сплюнув', 0.14285714285714285)],
#  ('лучезарного', 'армии'): [('союзников', 1.0)],
#  ('армии', 'союзников'): [('уверенно', 1.0)],
#  ('союзников', 'уверенно'): [('продвигаются', 1.0)],
#  ('уверенно', 'продвигаются'): [('к', 1.0)],
#  ('продвигаются', 'к'): [('храму', 1.0)],
#  ('к', 'храму'): [('тиамат', 0.17857142857142858),
#   ('альянс', 0.03571428571428571),
#   ('наверняка', 0.03571428571428571),
#   ('и', 0.03571428571428571),
#   ('спящих', 0.03571428571428571),
#   ('вместе', 0.03571428571428571),
#   ('он', 0.07142857142857142),
#   ('в', 0.03571428571428571),
#   ('двигалось', 0.03571428571428571),
#   ('со', 0.03571428571428571),
#   ('никто', 0.03571428571428571),
#   ('я', 0.03571428571428571),
#   ('многомудрой', 0.03571428571428571),
#   ('на', 0.07142857142857142),
#   ('ко', 0.03571428571428571),
#   ('йеми', 0.03571428571428571),
#   ('там', 0.07142857142857142),
#   ('триста', 0.03571428571428571),
#   ('не', 0.07142857142857142),
#   ('к', 0.03571428571428571)],
#  ('храму', 'тиамат'): [('старые', 0.16666666666666666),
#   ('разбирает', 0.16666666666666666),
#   ('у', 0.16666666666666666),
#   ('остатки', 0.16666666666666666),
#   ('а', 0.3333333333333333)],
#  ('тиамат', 'старые'): [('фокусы', 1.0)],
#  ('старые', 'фокусы'): [('скифа', 1.0)],
#  ('фокусы', 'скифа'): [('больше', 1.0)],
#  ('скифа', 'больше'): [('не', 0.5), ('трехсот', 0.5)],
#  ('больше', 'не'): [('работают', 0.043478260869565216),
#   ('встанет', 0.043478260869565216),
#   ('было', 0.043478260869565216),
#   ('платить', 0.043478260869565216),
#   ('сбежал', 0.043478260869565216),
#   ('бил', 0.043478260869565216),
#   ('смогу', 0.043478260869565216),
#   ('существует', 0.043478260869565216),
#   ('держало', 0.043478260869565216),
#   ('одни', 0.043478260869565216),
#   ('шарообразный', 0.043478260869565216),
#   ('отпускал', 0.043478260869565216),
#   ('перевес', 0.043478260869565216),
#   ('демонстрировал', 0.043478260869565216),
#   ('гипнотизирую', 0.043478260869565216),
#   ('тронет', 0.043478260869565216),
#   ('испытывающая', 0.043478260869565216),
#   ('являетесь', 0.043478260869565216),
#   ('сказала', 0.043478260869565216),
#   ('встали', 0.043478260869565216),
#   ('работали', 0.043478260869565216),
#   ('теряя', 0.043478260869565216),
#   ('нежить', 0.043478260869565216)],
#  ('не', 'работают'): [('легат', 1.0)],
#  ('работают', 'легат'): [('чумного', 1.0)],
#  ('легат', 'чумного'): [('мора', 1.0)],
#  ('чумного', 'мора'): [('и', 0.09090909090909091),
#   ('то', 0.011363636363636364),
#   ('в', 0.03409090909090909),
#   ('чтобы', 0.022727272727272728),
#   ('однако', 0.011363636363636364),
#   ('скиф', 0.011363636363636364),
#   ('за', 0.011363636363636364),
#   ('большой', 0.011363636363636364),
#   ('под', 0.011363636363636364),
#   ('как', 0.022727272727272728),
#   ('получает', 0.011363636363636364),
#   ('когда-то', 0.011363636363636364),
#   ('а', 0.03409090909090909),
#   ('пробивали', 0.011363636363636364),
#   ('я', 0.03409090909090909),
#   ('вот', 0.022727272727272728),
#   ('завершится', 0.011363636363636364),
#   ('или', 0.011363636363636364),
#   ('почему-то', 0.011363636363636364),
#   ('аура', 0.011363636363636364),
#   ('остались', 0.011363636363636364),
#   ('успешно', 0.011363636363636364),
#   ('да', 0.011363636363636364),
#   ('ибо', 0.011363636363636364),
#   ('вскоре', 0.011363636363636364),
#   ('но', 0.022727272727272728),
#   ('пустовал', 0.011363636363636364),
#   ('лич', 0.011363636363636364),
#   ('доступно', 0.011363636363636364),
#   ('вы', 0.022727272727272728),
#   ('бессмертие', 0.011363636363636364),
#   ('оно', 0.011363636363636364),
#   ('иконки', 0.011363636363636364),
#   ('мы', 0.011363636363636364),
#   ('максимум', 0.011363636363636364),
#   ('невероятно', 0.011363636363636364),
#   ('мысль', 0.011363636363636364),
#   ('продолжало', 0.011363636363636364),
#   ('нужно', 0.022727272727272728),
#   ('ваша', 0.022727272727272728),
#   ('понижена', 0.022727272727272728),
#   ('сильных', 0.011363636363636364),
#   ('требуется', 0.011363636363636364),
#   ('его', 0.011363636363636364),
#   ('отказываться', 0.011363636363636364),
#   ('причем', 0.011363636363636364),
#   ('погибли', 0.011363636363636364),
#   ('пошатнулись', 0.011363636363636364),
#   ('нет', 0.011363636363636364),
#   ('понятно', 0.011363636363636364),
#   ('пробились', 0.011363636363636364),
#   ('работало', 0.011363636363636364),
#   ('хотя', 0.011363636363636364),
#   ('не', 0.011363636363636364),
#   ('полностью', 0.011363636363636364),
#   ('возмездием', 0.011363636363636364),
#   ('лязгнула', 0.011363636363636364),
#   ('удален', 0.022727272727272728),
#   ('оставалось', 0.011363636363636364),
#   ('существо', 0.011363636363636364),
#   ('неписей', 0.011363636363636364),
#   ('оказался', 0.011363636363636364),
#   ('голосовая', 0.011363636363636364),
#   ('сноусторм', 0.011363636363636364),
#   ('верно', 0.011363636363636364),
#   ('обещанный', 0.011363636363636364)],
#  ('мора', 'и'): [('его', 0.125),
#   ('выдает', 0.125),
#   ('получает', 0.125),
#   ('с', 0.125),
#   ('автоматически', 0.125),
#   ('инициала', 0.125),
#   ('начинался', 0.125),
#   ('рита', 0.125)],
#  ('и', 'его'): [('друзья', 0.21739130434782608),
#   ('клан', 0.08695652173913043),
#   ('напарнику', 0.043478260869565216),
#   ('напарник', 0.043478260869565216),
#   ('жена', 0.043478260869565216),
#   ('а', 0.043478260869565216),
#   ('поведение', 0.043478260869565216),
#   ('клана', 0.043478260869565216),
#   ('соратники', 0.043478260869565216),
#   ('школа', 0.043478260869565216),
#   ('надежным', 0.043478260869565216),
#   ('или', 0.043478260869565216),
#   ('нужно', 0.043478260869565216),
#   ('жреца', 0.08695652173913043),
#   ('офицеры', 0.043478260869565216),
#   ('но', 0.043478260869565216),
#   ('хилеры', 0.043478260869565216)],
#  ('его', 'друзья'): [('стоят', 0.2),
#   ('создают', 0.2),
#   ('выигрывают', 0.2),
#   ('используют', 0.2),
#   ('безопасник', 0.2)],
#  ('друзья', 'стоят'): [('перед', 1.0)],
#  ('стоят', 'перед'): [('нелегким', 1.0)],
#  ('перед', 'нелегким'): [('выбором', 1.0)],
#  ('нелегким', 'выбором'): [('подчиниться', 1.0)],
#  ('выбором', 'подчиниться'): [('пожеланиям', 1.0)],
#  ('подчиниться', 'пожеланиям'): [('корпорации', 1.0)],
#  ('пожеланиям', 'корпорации'): [('сноусторм', 1.0)],
#  ('корпорации', 'сноусторм'): [('и', 1.0)],
#  ('сноусторм', 'и'): [('выполнить', 0.5), ('не', 0.5)],
#  ('и', 'выполнить'): [('задание', 1.0)],
#  ('выполнить', 'задание'): [('ядра', 1.0)],
#  ('задание', 'ядра'): [('сдаться', 1.0)],
#  ('ядра', 'сдаться'): [('превентивам', 1.0)],
#  ('сдаться', 'превентивам'): [('или', 1.0)],
#  ('превентивам', 'или'): [('отступить', 1.0)],
#  ('или', 'отступить'): [('в', 1.0)],
#  ('отступить', 'в'): [('битве', 1.0)],
#  ('в', 'битве'): [('за', 0.2),
#   ('да', 0.2),
#   ('под', 0.2),
#   ('я', 0.2),
#   ('заверил', 0.2)],
#  ('битве', 'за'): [('храм', 1.0)],
#  ('за', 'храм'): [('тиамат', 0.75), ('с', 0.25)],
#  ('храм', 'тиамат'): [('чтобы', 0.05263157894736842),
#   ('одной', 0.05263157894736842),
#   ('на', 0.05263157894736842),
#   ('так', 0.05263157894736842),
#   ('одержит', 0.05263157894736842),
#   ('сейчас', 0.05263157894736842),
#   ('беззащитен', 0.05263157894736842),
#   ('и', 0.10526315789473684),
#   ('сам', 0.05263157894736842),
#   ('кивнув', 0.05263157894736842),
#   ('стражи', 0.05263157894736842),
#   ('надежной', 0.05263157894736842),
#   ('путь', 0.05263157894736842),
#   ('был', 0.05263157894736842),
#   ('когда', 0.05263157894736842),
#   ('началась', 0.05263157894736842),
#   ('итак', 0.05263157894736842),
#   ('ты', 0.05263157894736842)],
#  ('тиамат', 'чтобы'): [('выиграть', 0.5), ('показать', 0.5)],
#  ('чтобы', 'выиграть'): [('войну', 0.5), ('время', 0.5)],
#  ('выиграть', 'войну'): [('ясно', 1.0)],
#  ('войну', 'ясно'): [('одно', 1.0)],
#  ('ясно', 'одно'): [('без', 1.0)],
#  ('одно', 'без'): [('союзников', 1.0)],
#  ('без', 'союзников'): [('не', 1.0)],
#  ('союзников', 'не'): [('обойтись', 1.0)],
#  ('не', 'обойтись'): [('ведь', 0.25),
#   ('галлахеры', 0.25),
#   ('без', 0.25),
#   ('землю', 0.25)],
#  ('обойтись', 'ведь'): [('иногда', 1.0)],
#  ('ведь', 'иногда'): [('лучшие', 1.0)],
#  ('иногда', 'лучшие'): [('друзья', 1.0)],
#  ('лучшие', 'друзья'): [('получаются', 1.0)],
#  ('друзья', 'получаются'): [('из', 1.0)],
#  ('получаются', 'из'): [('бывших', 1.0)],
#  ('из', 'бывших'): [('врагов', 1.0)],
#  ('бывших', 'врагов'): [('данияр', 1.0)],
#  ('врагов', 'данияр'): [('сугралинов', 1.0)],
#  ('данияр', 'сугралинов'): [('дисгардиум', 1.0)],
#  ('война', 'краткое'): [('содержание', 1.0)],
#  ('краткое', 'содержание'): [('предыдущих', 1.0)],
#  ('содержание', 'предыдущих'): [('книг', 1.0)],
#  ('предыдущих', 'книг'): [('краткая', 1.0)],
#  ('книг', 'краткая'): [('история', 1.0)],
#  ('краткая', 'история'): [('будущего', 1.0)],
#  ('история', 'будущего'): [('в', 1.0)],
#  ('будущего', 'в'): [('2048', 1.0)],
#  ('в', '2048'): [('году', 1.0)],
#  ('2048', 'году'): [('население', 1.0)],
#  ('году', 'население'): [('земли', 1.0)],
#  ('население', 'земли'): [('достигло', 1.0)],
#  ('земли', 'достигло'): [('пятнадцати', 1.0)],
#  ('достигло', 'пятнадцати'): [('миллиардов', 1.0)],
#  ('пятнадцати', 'миллиардов'): [('практически', 1.0)],
#  ('миллиардов', 'практически'): [('всю', 1.0)],
#  ('практически', 'всю'): [('работу', 1.0)],
#  ('всю', 'работу'): [('выполняют', 1.0)],
#  ('работу', 'выполняют'): [('роботы', 1.0)],
#  ('выполняют', 'роботы'): [('число', 1.0)],
#  ('роботы', 'число'): [('нетрудоспособных', 1.0)],
#  ('число', 'нетрудоспособных'): [('людей', 1.0)],
#  ('нетрудоспособных', 'людей'): [('растет', 1.0)],
#  ('людей', 'растет'): [('в', 1.0)],
#  ('растет', 'в'): [('геометрической', 0.3333333333333333),
#   ('цене', 0.3333333333333333),
#   ('три', 0.3333333333333333)],
#  ('в', 'геометрической'): [('прогрессии', 1.0)],
#  ('геометрической', 'прогрессии'): [('они', 1.0)],
#  ('прогрессии', 'они'): [('будучи', 1.0)],
#  ('они', 'будучи'): [('трутнями', 1.0)],
#  ('будучи', 'трутнями'): [('отъедают', 1.0)],
#  ('трутнями', 'отъедают'): [('более', 1.0)],
#  ('отъедают', 'более'): [('половины', 1.0)],
#  ('более', 'половины'): [('мировых', 1.0)],
#  ('половины', 'мировых'): [('ресурсов', 1.0)],
#  ('мировых', 'ресурсов'): [('под', 1.0)],
#  ('ресурсов', 'под'): [('гнетом', 1.0)],
#  ('под', 'гнетом'): [('огромных', 1.0)],
#  ('гнетом', 'огромных'): [('подоходных', 1.0)],
#  ('огромных', 'подоходных'): [('налогов', 1.0)],
#  ('подоходных', 'налогов'): [('по', 1.0)],
#  ('налогов', 'по'): [('всему', 1.0)],
#  ('по', 'всему'): [('миру', 0.1),
#   ('полю', 0.1),
#   ('дисгардиуму', 0.1),
#   ('особенности', 0.1),
#   ('списку', 0.1),
#   ('туловищу', 0.1),
#   ('просто', 0.1),
#   ('айлин', 0.1),
#   ('дису', 0.1),
#   ('тоже', 0.1)],
#  ('всему', 'миру'): [('вспыхивают', 0.5), ('все', 0.5)],
#  ('миру', 'вспыхивают'): [('бунты', 1.0)],
#  ('вспыхивают', 'бунты'): [('и', 1.0)],
#  ('бунты', 'и'): [('восстания', 1.0)],
#  ('и', 'восстания'): [('один', 1.0)],
#  ('восстания', 'один'): [('за', 1.0)],
#  ('один', 'за'): [('другим', 1.0)],
#  ('за', 'другим'): [('следуют', 0.16666666666666666),
#   ('обычными', 0.16666666666666666),
#   ('в', 0.16666666666666666),
#   ('влил', 0.16666666666666666),
#   ('они', 0.16666666666666666),
#   ('лопнули', 0.16666666666666666)],
#  ('другим', 'следуют'): [('теракты', 1.0)],
#  ('следуют', 'теракты'): [('пророки', 1.0)],
#  ('теракты', 'пророки'): [('и', 1.0)],
#  ('пророки', 'и'): [('предсказатели', 1.0)],
#  ('и', 'предсказатели'): [('предвещают', 1.0)],
#  ('предсказатели', 'предвещают'): [('конец', 1.0)],
#  ('предвещают', 'конец'): [('света', 1.0)],
#  ('конец', 'света'): [('часть', 1.0)],
#  ('света', 'часть'): [('стран', 1.0)],
#  ('часть', 'стран'): [('отказывается', 1.0)],
#  ('стран', 'отказывается'): [('от', 1.0)],
#  ('отказывается', 'от'): [('содержания', 0.5), ('комментариев', 0.5)],
#  ('от', 'содержания'): [('армии', 1.0)],
#  ('содержания', 'армии'): [('не', 1.0)],
#  ('армии', 'не'): [('в', 1.0)],
#  ('не', 'в'): [('силах', 0.0967741935483871),
#   ('состоянии', 0.03225806451612903),
#   ('словах', 0.03225806451612903),
#   ('год', 0.03225806451612903),
#   ('моих', 0.06451612903225806),
#   ('дороговизне', 0.03225806451612903),
#   ('одиночку', 0.03225806451612903),
#   ('первый', 0.06451612903225806),
#   ('реале', 0.03225806451612903),
#   ('курсе', 0.16129032258064516),
#   ('кого', 0.03225806451612903),
#   ('порядке', 0.0967741935483871),
#   ('моем', 0.03225806451612903),
#   ('безопасности', 0.06451612903225806),
#   ('учебе', 0.03225806451612903),
#   ('игре', 0.03225806451612903),
#   ('абилках', 0.03225806451612903),
#   ('дисгардиуме', 0.03225806451612903),
#   ('десять', 0.03225806451612903),
#   ('дисе', 0.03225806451612903)],
#  ('в', 'силах'): [('прокормить', 0.3333333333333333),
#   ('выдержать', 0.3333333333333333),
#   ('даже', 0.3333333333333333)],
#  ('силах', 'прокормить'): [('собственных', 1.0)],
#  ('прокормить', 'собственных'): [('граждан', 1.0)],
#  ('собственных', 'граждан'): [('мировые', 1.0)],
#  ('граждан', 'мировые'): [('корпорации', 1.0)],
#  ('мировые', 'корпорации'): [('диктуют', 1.0)],
#  ('корпорации', 'диктуют'): [('условия', 1.0)],
#  ('диктуют', 'условия'): [('странам', 1.0)],
#  ('условия', 'странам'): [('и', 1.0)],
#  ('странам', 'и'): [('регионам', 1.0)],
#  ('и', 'регионам'): [('бунтующие', 1.0)],
#  ('регионам', 'бунтующие'): [('громят', 1.0)],
#  ('бунтующие', 'громят'): [('ненавистных', 1.0)],
#  ('громят', 'ненавистных'): [('эксплуататоров', 1.0)],
#  ('ненавистных', 'эксплуататоров'): [('но', 1.0)],
#  ('эксплуататоров', 'но'): [('остаются', 1.0)],
#  ('но', 'остаются'): [('без', 1.0)],
#  ('остаются', 'без'): [('гуманитарной', 1.0)],
#  ('без', 'гуманитарной'): [('помощи', 1.0)],
#  ('гуманитарной', 'помощи'): [('против', 1.0)],
#  ('помощи', 'против'): [('этих', 1.0)],
#  ('против', 'этих'): [('территорий', 1.0)],
#  ('этих', 'территорий'): [('введено', 1.0)],
#  ('территорий', 'введено'): [('торговое', 1.0)],
#  ('введено', 'торговое'): [('эмбарго', 1.0)],
#  ('торговое', 'эмбарго'): [('в', 1.0)],
#  ('эмбарго', 'в'): [('азии', 1.0)],
#  ('в', 'азии'): [('вспыхивает', 1.0)],
#  ('азии', 'вспыхивает'): [('эпидемия', 1.0)],
#  ('вспыхивает', 'эпидемия'): [('от', 1.0)],
#  ('эпидемия', 'от'): [('нулевого', 1.0)],
#  ('от', 'нулевого'): [('пациента', 1.0)],
#  ('нулевого', 'пациента'): [('до', 1.0)],
#  ('пациента', 'до'): [('гибели', 1.0)],
#  ('до', 'гибели'): [('миллиардной', 0.3333333333333333),
#   ('дэка', 0.3333333333333333),
#   ('шазза', 0.3333333333333333)],
#  ('гибели', 'миллиардной'): [('жертвы', 1.0)],
#  ('миллиардной', 'жертвы'): [('нового', 1.0)],
#  ('жертвы', 'нового'): [('вируса', 1.0)],
#  ('нового', 'вируса'): [('проходит', 1.0)],
#  ('вируса', 'проходит'): [('неделя', 1.0)],
#  ('проходит', 'неделя'): [('африка', 1.0)],
#  ('неделя', 'африка'): [('вымирает', 1.0)],
#  ('африка', 'вымирает'): [('от', 1.0)],
#  ('вымирает', 'от'): [('нехватки', 1.0)],
#  ('от', 'нехватки'): [('питьевой', 1.0)],
#  ('нехватки', 'питьевой'): [('воды', 1.0)],
#  ('питьевой', 'воды'): [('и', 1.0)],
#  ('воды', 'и'): [('голода', 1.0)],
#  ('и', 'голода'): [('миллионы', 1.0)],
#  ('голода', 'миллионы'): [('беженцев', 1.0)],
#  ('миллионы', 'беженцев'): [('каждый', 1.0)],
#  ('беженцев', 'каждый'): [('день', 1.0)],
#  ('каждый', 'день'): [('вторгаются', 0.3333333333333333),
#   ('объявляют', 0.3333333333333333),
#   ('мы', 0.3333333333333333)],
#  ('день', 'вторгаются'): [('на', 1.0)],
#  ('вторгаются', 'на'): [('территорию', 1.0)],
#  ('на', 'территорию'): [('европы', 1.0)],
#  ('территорию', 'европы'): [('и', 1.0)],
#  ('европы', 'и'): [('азии', 1.0)],
#  ('и', 'азии'): [('сша', 1.0)],
#  ('азии', 'сша'): [('закрывают', 1.0)],
#  ('сша', 'закрывают'): [('границы', 1.0)],
#  ('закрывают', 'границы'): [('религиозные', 1.0)],
#  ('границы', 'религиозные'): [('радикальные', 1.0)],
#  ('религиозные', 'радикальные'): [('секты', 1.0)],
#  ('радикальные', 'секты'): [('каждый', 1.0)],
#  ('секты', 'каждый'): [('день', 1.0)],
#  ('день', 'объявляют'): [('о', 1.0)],
#  ('объявляют', 'о'): [('новых', 1.0)],
#  ('о', 'новых'): [('независимых', 0.5), ('бонусах', 0.5)],
#  ('новых', 'независимых'): [('территориях', 1.0)],
#  ('независимых', 'территориях'): [('китай', 1.0)],
#  ('территориях', 'китай'): [('вторгается', 1.0)],
#  ('китай', 'вторгается'): [('на', 1.0)],
#  ('вторгается', 'на'): [('дальний', 1.0)],
#  ('на', 'дальний'): [('восток', 1.0)],
#  ('дальний', 'восток'): [('в', 1.0)],
#  ('восток', 'в'): [('корею', 1.0)],
#  ('в', 'корею'): [('таиланд', 1.0)],
#  ('корею', 'таиланд'): [('вьетнам', 1.0)],
#  ('таиланд', 'вьетнам'): [('и', 1.0)],
#  ('вьетнам', 'и'): [('японию', 1.0)],
#  ('и', 'японию'): [('сша', 1.0)],
#  ('японию', 'сша'): [('использует', 1.0)],
#  ('сша', 'использует'): [('ядерное', 1.0)],
#  ('использует', 'ядерное'): [('оружие', 1.0)],
#  ('ядерное', 'оружие'): [('россия', 1.0)],
#  ('оружие', 'россия'): [('отвечает', 1.0)],
#  ('россия', 'отвечает'): [('что', 1.0)],
#  ('отвечает', 'что'): [('провоцирует', 1.0)],
#  ('что', 'провоцирует'): [('новые', 1.0)],
#  ('провоцирует', 'новые'): [('природные', 1.0)],
#  ('новые', 'природные'): [('катаклизмы', 1.0)],
#  ('природные', 'катаклизмы'): [('северные', 1.0)],
#  ('катаклизмы', 'северные'): [('провинции', 1.0)],
#  ('северные', 'провинции'): [('китая', 1.0)],
#  ('провинции', 'китая'): [('перестают', 1.0)],
#  ('китая', 'перестают'): [('существовать', 1.0)],
#  ('перестают', 'существовать'): [('их', 1.0)],
#  ('существовать', 'их'): [('территории', 1.0)],
#  ('их', 'территории'): [('превращаются', 1.0)],
#  ('территории', 'превращаются'): [('в', 1.0)],
#  ('превращаются', 'в'): [('радиоактивные', 1.0)],
#  ('в', 'радиоактивные'): [('пустоши', 1.0)],
#  ('радиоактивные', 'пустоши'): [('ответный', 1.0)],
#  ('пустоши', 'ответный'): [('удар', 1.0)],
#  ('ответный', 'удар'): [('китая', 1.0)],
#  ('удар', 'китая'): [('русским', 1.0)],
#  ('китая', 'русским'): [('удается', 1.0)],
#  ('русским', 'удается'): [('предотвратить', 1.0)],
#  ('удается', 'предотвратить'): [('за', 1.0)],
#  ('предотвратить', 'за'): [('счет', 1.0)],
#  ('за', 'счет'): [('превентивного', 0.043478260869565216),
#   ('чего', 0.043478260869565216),
#   ('захваченной', 0.043478260869565216),
#   ('пустынных', 0.043478260869565216),
#   ('артефактов', 0.043478260869565216),
#   ('алмазной', 0.043478260869565216),
#   ('этого', 0.043478260869565216),
#   ('договоров', 0.043478260869565216),
#   ('заведения', 0.043478260869565216),
#   ('встроенного', 0.043478260869565216),
#   ('первого', 0.043478260869565216),
#   ('наших', 0.043478260869565216),
#   ('каблуков', 0.043478260869565216),
#   ('штрафов', 0.043478260869565216),
#   ('того', 0.043478260869565216),
#   ('наносимого', 0.043478260869565216),
#   ('чего-то', 0.043478260869565216),
#   ('моего', 0.08695652173913043),
#   ('продвинутого', 0.043478260869565216),
#   ('взлетевшей', 0.043478260869565216),
#   ('содействия', 0.043478260869565216),
#   ('возмездий', 0.043478260869565216)],
#  ('счет', 'превентивного'): [('саботажа', 1.0)],
#  ('превентивного', 'саботажа'): [('но', 1.0)],
#  ('саботажа', 'но'): [('это', 1.0)],
#  ('но', 'это'): [('только', 0.125),
#   ('мы', 0.0625),
#   ('так', 0.0625),
#   ('вызовет', 0.0625),
#   ('ненадолго', 0.0625),
#   ('не', 0.125),
#   ('уже', 0.0625),
#   ('вряд', 0.0625),
#   ('слабо', 0.0625),
#   ('на', 0.0625),
#   ('меня', 0.0625),
#   ('к', 0.0625),
#   ('длилось', 0.0625),
#   ('еще', 0.0625)],
#  ('это', 'только'): [('начало', 0.25),
#   ('из', 0.25),
#   ('тогда', 0.25),
#   ('до', 0.25)],
#  ('только', 'начало'): [('силы', 1.0)],
#  ('начало', 'силы'): [('нато', 1.0)],
#  ('силы', 'нато'): [('вторгаются', 1.0)],
#  ('нато', 'вторгаются'): [('в', 1.0)],
#  ('вторгаются', 'в'): [('россию', 0.5), ('лахарийскую', 0.5)],
#  ('в', 'россию'): [('однако', 1.0)],
#  ('россию', 'однако'): [('приостанавливают', 1.0)],
#  ('однако', 'приостанавливают'): [('вторжение', 1.0)],
#  ('приостанавливают', 'вторжение'): [('под', 1.0)],
#  ('вторжение', 'под'): [('угрозой', 1.0)],
#  ('под', 'угрозой'): [('полномасштабной', 1.0)],
#  ('угрозой', 'полномасштабной'): [('ядерной', 1.0)],
#  ('полномасштабной', 'ядерной'): [('войны', 1.0)],
#  ('ядерной', 'войны'): [('стороны', 1.0)],
#  ('войны', 'стороны'): [('садятся', 1.0)],
#  ('стороны', 'садятся'): [('за', 1.0)],
#  ('садятся', 'за'): [('стол', 1.0)],
#  ('за', 'стол'): [('переговоров', 0.5), ('голос', 0.5)],
#  ('стол', 'переговоров'): [('и', 1.0)],
#  ('переговоров', 'и'): [('заключают', 1.0)],
#  ('и', 'заключают'): [('мир', 1.0)],
#  ('заключают', 'мир'): [('третья', 1.0)],
#  ('мир', 'третья'): [('мировая', 1.0)],
#  ('третья', 'мировая'): [('война', 0.5), ('хорваца', 0.5)],
#  ('мировая', 'война'): [('длилась', 1.0)],
#  ('война', 'длилась'): [('меньше', 1.0)],
#  ('длилась', 'меньше'): [('месяца', 1.0)],
#  ('меньше', 'месяца'): [('в', 1.0)],
#  ('месяца', 'в'): [('2052-м', 1.0)],
#  ('в', '2052-м'): [('начинается', 1.0)],
#  ('2052-м', 'начинается'): [('принудительная', 1.0)],
#  ('начинается', 'принудительная'): [('глобализация', 1.0)],
#  ('принудительная', 'глобализация'): [('силами', 1.0)],
#  ('глобализация', 'силами'): [('миротворцев', 1.0)],
#  ('силами', 'миротворцев'): [('оон', 0.5), ('криминал', 0.5)],
#  ('миротворцев', 'оон'): [('становится', 1.0)],
#  ('оон', 'становится'): [('фактическим', 1.0)],
#  ('становится', 'фактическим'): [('мировым', 1.0)],
#  ('фактическим', 'мировым'): [('правительством', 1.0)],
#  ('мировым', 'правительством'): [('после', 1.0)],
#  ('правительством', 'после'): [('ряда', 1.0)],
#  ('после', 'ряда'): [('принятых', 1.0)],
#  ('ряда', 'принятых'): [('законов', 1.0)],
#  ('принятых', 'законов'): [('вводится', 1.0)],
#  ('законов', 'вводится'): [('показатель', 1.0)],
#  ('вводится', 'показатель'): [('социальной', 1.0)],
#  ('показатель', 'социальной'): [('значимости', 1.0)],
#  ('социальной', 'значимости'): [('отныне', 1.0)],
#  ('значимости', 'отныне'): [('блага', 1.0)],
#  ('отныне', 'блага'): [('и', 1.0)],
#  ('блага', 'и'): [('привилегии', 1.0)],
#  ('и', 'привилегии'): [('цивилизации', 1.0)],
#  ('привилегии', 'цивилизации'): [('доступны', 1.0)],
#  ('цивилизации', 'доступны'): [('лишь', 1.0)],
#  ('доступны', 'лишь'): [('гражданам', 1.0)],
#  ('лишь', 'гражданам'): [('людям', 1.0)],
#  ('гражданам', 'людям'): [('имеющим', 1.0)],
#  ('людям', 'имеющим'): [('значимость', 1.0)],
#  ('имеющим', 'значимость'): [('для', 1.0)],
#  ('значимость', 'для'): [('общества', 1.0)],
#  ('для', 'общества'): [('порядок', 0.3333333333333333),
#   ('а', 0.3333333333333333),
#   ('так', 0.3333333333333333)],
#  ('общества', 'порядок'): [('сохраняется', 1.0)],
#  ('порядок', 'сохраняется'): [('только', 1.0)],
#  ('сохраняется', 'только'): [('на', 1.0)],
#  ('только', 'на'): [('гражданских', 0.14285714285714285),
#   ('базаре', 0.14285714285714285),
#   ('тех', 0.14285714285714285),
#   ('брюхе', 0.14285714285714285),
#   ('сорок', 0.14285714285714285),
#   ('характеристики', 0.14285714285714285),
#   ('то', 0.14285714285714285)],
#  ('на', 'гражданских'): [('территориях', 1.0)],
#  ('гражданских', 'территориях'): [('неграждане', 1.0)],
#  ('территориях', 'неграждане'): [('живут', 1.0)],
#  ('неграждане', 'живут'): [('в', 1.0)],
#  ('живут', 'в'): [('местах', 0.5), ('зонах', 0.5)],
#  ('в', 'местах'): [('признанных', 1.0)],
#  ('местах', 'признанных'): [('непригодными', 1.0)],
#  ('признанных', 'непригодными'): [('для', 1.0)],
#  ('непригодными', 'для'): [('жизни', 1.0)],
#  ('для', 'жизни'): [('в', 0.3333333333333333),
#   ('граждан', 0.3333333333333333),
#   ('показатели', 0.3333333333333333)],
#  ('жизни', 'в'): [('силу', 0.125),
#   ('бездне', 0.25),
#   ('клане', 0.125),
#   ('дверь', 0.125),
#   ('секунду', 0.125),
#   ('минуту', 0.125),
#   ('сто', 0.125)],
#  ('в', 'силу'): [('плохой', 0.5), ('с', 0.5)],
#  ('силу', 'плохой'): [('экологической', 1.0)],
#  ('плохой', 'экологической'): [('обстановки', 1.0)],
#  ('экологической', 'обстановки'): [('климата', 1.0)],
#  ('обстановки', 'климата'): [('или', 1.0)],
#  ('климата', 'или'): [('повышенной', 1.0)],
#  ('или', 'повышенной'): [('радиационной', 1.0)],
#  ('повышенной', 'радиационной'): [('опасности', 1.0)],
#  ('радиационной', 'опасности'): [('с', 1.0)],
#  ('опасности', 'с'): [('каждым', 1.0)],
#  ('с', 'каждым'): [('годом', 0.1),
#   ('уровнем', 0.1),
#   ('договора', 0.1),
#   ('попаданием', 0.1),
#   ('заходом', 0.1),
#   ('убийством', 0.1),
#   ('кланом', 0.1),
#   ('моим', 0.1),
#   ('шагом', 0.1),
#   ('убитым', 0.1)],
#  ('каждым', 'годом'): [('оон', 1.0)],
#  ('годом', 'оон'): [('ужесточает', 1.0)],
#  ('оон', 'ужесточает'): [('наказания', 1.0)],
#  ('ужесточает', 'наказания'): [('за', 1.0)],
#  ('наказания', 'за'): [('любые', 1.0)],
#  ('за', 'любые'): [('преступления', 1.0)],
#  ('любые', 'преступления'): [('даже', 1.0)],
#  ('преступления', 'даже'): [('банальное', 1.0)],
#  ('даже', 'банальное'): [('воровство', 1.0)],
#  ('банальное', 'воровство'): [('в', 1.0)],
#  ('воровство', 'в'): [('супермаркете', 1.0)],
#  ('в', 'супермаркете'): [('может', 1.0)],
#  ('супермаркете', 'может'): [('караться', 1.0)],
#  ('может', 'караться'): [('смертной', 1.0)],
#  ('караться', 'смертной'): [('казнью', 1.0)],
#  ('смертной', 'казнью'): [('все', 1.0)],
#  ('казнью', 'все'): [('направлено', 1.0)],
#  ('все', 'направлено'): [('на', 1.0)],
#  ('направлено', 'на'): [('очищение', 1.0)],
#  ('на', 'очищение'): [('и', 1.0)],
#  ('очищение', 'и'): [('селекцию', 1.0)],
#  ('и', 'селекцию'): [('человеческого', 1.0)],
#  ('селекцию', 'человеческого'): [('вида', 1.0)],
#  ('человеческого', 'вида'): [('набирает', 1.0)],
#  ('вида', 'набирает'): [('популярность', 1.0)],
#  ('набирает', 'популярность'): [('евгеника', 1.0)],
#  ('популярность', 'евгеника'): [('от', 1.0)],
#  ('евгеника', 'от'): [('масштабного', 1.0)],
#  ('от', 'масштабного'): [('геноцида', 1.0)],
#  ('масштабного', 'геноцида'): [('власти', 1.0)],
#  ('геноцида', 'власти'): [('удерживает', 1.0)],
#  ('власти', 'удерживает'): [('страх', 1.0)],
#  ('удерживает', 'страх'): [('перед', 1.0)],
#  ('страх', 'перед'): [('хаосом', 1.0)],
#  ('перед', 'хаосом'): [('и', 1.0)],
#  ('хаосом', 'и'): [('вооруженным', 1.0)],
#  ('и', 'вооруженным'): [('сопротивлением', 1.0)],
#  ('вооруженным', 'сопротивлением'): [('у', 1.0)],
#  ('сопротивлением', 'у'): [('каждого', 1.0)],
#  ('у', 'каждого'): [('миротворца', 0.25),
#   ('из', 0.25),
#   ('идеальные', 0.25),
#   ('насчитывалось', 0.25)],
#  ('каждого', 'миротворца'): [('есть', 0.5), ('армия', 0.5)],
#  ('миротворца', 'есть'): [('родственники', 1.0)],
#  ('есть', 'родственники'): [('среди', 1.0)],
#  ('родственники', 'среди'): [('неграждан', 1.0)],
#  ('среди', 'неграждан'): [('и', 1.0)],
#  ('неграждан', 'и'): [('потенциально', 0.3333333333333333),
#   ('самые', 0.3333333333333333),
#   ('йорубу', 0.3333333333333333)],
#  ('и', 'потенциально'): [('необходимые', 1.0)],
#  ('потенциально', 'необходимые'): [('человеческие', 1.0)],
#  ('необходимые', 'человеческие'): [('ресурсы', 1.0)],
#  ('человеческие', 'ресурсы'): [('для', 1.0)],
#  ('ресурсы', 'для'): [('колонизации', 0.5), ('комфортных', 0.5)],
#  ('для', 'колонизации'): [('солнечной', 1.0)],
#  ('колонизации', 'солнечной'): [('системы', 1.0)],
#  ('солнечной', 'системы'): [('ученые', 0.5), ('я', 0.5)],
#  ('системы', 'ученые'): [('предсказывают', 1.0)],
#  ('ученые', 'предсказывают'): [('крах', 1.0)],
#  ('предсказывают', 'крах'): [('системы', 1.0)],
#  ('крах', 'системы'): [('гражданства', 1.0)],
#  ('системы', 'гражданства'): [('и', 1.0)],
#  ('гражданства', 'и'): [('кризис', 1.0)],
#  ('и', 'кризис'): [('продовольствия', 1.0)],
#  ('кризис', 'продовольствия'): [('более', 1.0)],
#  ('продовольствия', 'более'): [('того', 1.0)],
#  ('более', 'того'): [('недовольство', 0.2),
#   ('место', 0.2),
#   ('хайро', 0.2),
#   ('никогда', 0.2),
#   ('на', 0.2)],
#  ('того', 'недовольство'): [('растет', 1.0)],
#  ('недовольство', 'растет'): [('бурно', 1.0)],
#  ('растет', 'бурно'): [('развиваются', 1.0)],
#  ('бурно', 'развиваются'): [('оппозиционные', 1.0)],
#  ('развиваются', 'оппозиционные'): [('течения', 1.0)],
#  ('оппозиционные', 'течения'): [('жестоко', 1.0)],
#  ('течения', 'жестоко'): [('подавляемые', 1.0)],
#  ('жестоко', 'подавляемые'): [('силами', 1.0)],
#  ('подавляемые', 'силами'): [('миротворцев', 1.0)],
#  ('миротворцев', 'криминал'): [('по', 1.0)],
#  ('криминал', 'по'): [('большей', 1.0)],
#  ('по', 'большей'): [('части', 1.0)],
#  ('большей', 'части'): [('процветает', 0.2),
#   ('было', 0.2),
#   ('нечеловеческий', 0.2),
#   ('все', 0.2),
#   ('игроков', 0.2)],
#  ('части', 'процветает'): [('среди', 1.0)],
#  ('процветает', 'среди'): [('неграждан', 1.0)],
#  ('и', 'самые'): [('богатые', 1.0)],
#  ('самые', 'богатые'): [('из', 1.0)],
#  ('богатые', 'из'): [('них', 1.0)],
#  ('из', 'них'): [('выстраивают', 0.05),
#   ('добегал', 0.05),
#   ('стремится', 0.05),
#   ('нежить', 0.05),
#   ('может', 0.05),
#   ('чтобы', 0.05),
#   ('не', 0.15),
#   ('треть', 0.05),
#   ('можно', 0.05),
#   ('я', 0.05),
#   ('саян', 0.05),
#   ('угроза', 0.05),
#   ('прижимаясь', 0.05),
#   ('ядро', 0.05),
#   ('логово', 0.05),
#   ('попало', 0.05),
#   ('вообще', 0.05),
#   ('активировал', 0.05)],
#  ('них', 'выстраивают'): [('себе', 1.0)],
#  ('выстраивают', 'себе'): [('огромные', 1.0)],
#  ('себе', 'огромные'): [('особняки', 1.0)],
#  ('огромные', 'особняки'): [('и', 1.0)],
#  ('особняки', 'и'): [('дворцы', 1.0)],
#  ('и', 'дворцы'): [('в', 1.0)],
#  ('дворцы', 'в'): [('зонах', 1.0)],
#  ('в', 'зонах'): [('признанных', 0.3333333333333333),
#   ('обычно', 0.3333333333333333),
#   ('им', 0.3333333333333333)],
#  ('зонах', 'признанных'): [('неподходящими', 1.0)],
#  ('признанных', 'неподходящими'): [('для', 1.0)],
#  ('неподходящими', 'для'): [('жизни', 1.0)],
#  ('жизни', 'граждан'): [('чтобы', 1.0)],
#  ('граждан', 'чтобы'): [('занять', 1.0)],
#  ('чтобы', 'занять'): [('людей', 1.0)],
#  ('занять', 'людей'): [('в', 1.0)],
#  ('людей', 'в'): [('2055-м', 0.3333333333333333),
#   ('угол', 0.3333333333333333),
#   ('мире', 0.3333333333333333)],
#  ('в', '2055-м'): [('корпорация', 1.0)],
#  ('2055-м', 'корпорация'): [('сноусторм', 1.0)],
#  ('корпорация', 'сноусторм'): [('51', 1.0)],
#  ('сноусторм', '51'): [('участия', 1.0)],
#  ('51', 'участия'): [('оон', 1.0)],
#  ('участия', 'оон'): [('создает', 1.0)],
#  ('оон', 'создает'): [('игру', 1.0)],
#  ('создает', 'игру'): [('с', 1.0)],
#  ('игру', 'с'): [('полным', 1.0)],
#  ('с', 'полным'): [('погружением', 1.0)],
#  ('полным', 'погружением'): [('дисгардиум', 0.5), ('анонсированную', 0.5)],
#  ('погружением', 'дисгардиум'): [('неграждане', 1.0)],
#  ('дисгардиум', 'неграждане'): [('получают', 1.0)],
#  ('неграждане', 'получают'): [('работу', 1.0)],
#  ('получают', 'работу'): [('в', 1.0)],
#  ('работу', 'в'): [('виртуальном', 0.5), ('службе', 0.5)],
#  ('в', 'виртуальном'): [('мире', 1.0)],
#  ('виртуальном', 'мире'): [('рудокопы', 1.0)],
#  ('мире', 'рудокопы'): [('уборщики', 1.0)],
#  ('рудокопы', 'уборщики'): [('пастухи', 1.0)],
#  ('уборщики', 'пастухи'): [('сборщики', 1.0)],
#  ('пастухи', 'сборщики'): [('фруктов', 1.0)],
#  ('сборщики', 'фруктов'): [('а', 1.0)],
#  ('фруктов', 'а'): [('граждане', 1.0)],
#  ('а', 'граждане'): [('минимальную', 1.0)],
#  ('граждане', 'минимальную'): [('зарплату', 1.0)],
#  ('минимальную', 'зарплату'): [('за', 1.0)],
#  ('зарплату', 'за'): [('восьмичасовой', 1.0)],
#  ('за', 'восьмичасовой'): [('игровой', 1.0)],
#  ('восьмичасовой', 'игровой'): [('день', 1.0)],
#  ('игровой', 'день'): [('просто', 1.0)],
#  ('день', 'просто'): [('за', 1.0)],
#  ('просто', 'за'): [('оживление', 0.5), ('то', 0.5)],
#  ('за', 'оживление'): [('мира', 1.0)],
#  ('оживление', 'мира'): [('игра', 1.0)],
#  ('мира', 'игра'): [('максимально', 1.0)],
#  ('игра', 'максимально'): [('усложнена', 1.0)],
#  ('максимально', 'усложнена'): [('чтобы', 1.0)],
#  ('усложнена', 'чтобы'): [('дать', 1.0)],
#  ('чтобы', 'дать'): [('преимущество', 0.5), ('интервью', 0.5)],
#  ('дать', 'преимущество'): [('богатым', 1.0)],
#  ('преимущество', 'богатым'): [('и', 1.0)],
#  ('богатым', 'и'): [('растянуть', 1.0)],
#  ('и', 'растянуть'): [('игровой', 1.0)],
#  ('растянуть', 'игровой'): [('процесс', 1.0)],
#  ('игровой', 'процесс'): [('на', 1.0)],
#  ('процесс', 'на'): [('десятилетия', 1.0)],
#  ('на', 'десятилетия'): [('игровые', 1.0)],
#  ('десятилетия', 'игровые'): [('предметы', 1.0)],
#  ('игровые', 'предметы'): [('дороги', 1.0)],
#  ('предметы', 'дороги'): [('прокачка', 1.0)],
#  ('дороги', 'прокачка'): [('квестами', 1.0)],
#  ('прокачка', 'квестами'): [('и', 1.0)],
#  ('квестами', 'и'): [('убийствами', 1.0)],
#  ('и', 'убийствами'): [('мобов', 1.0)],
#  ('убийствами', 'мобов'): [('чрезмерно', 1.0)],
#  ('мобов', 'чрезмерно'): [('длительна', 1.0)],
#  ('чрезмерно', 'длительна'): [('максимально', 1.0)],
#  ('длительна', 'максимально'): [('достигнутый', 1.0)],
#  ('максимально', 'достигнутый'): [('уровень', 1.0)],
#  ('достигнутый', 'уровень'): [('в', 1.0)],
#  ('уровень', 'в'): [('игре', 1.0)],
#  ('в', 'игре'): [('за', 0.07692307692307693),
#   ('приближена', 0.07692307692307693),
#   ('дисгардиум', 0.07692307692307693),
#   ('но', 0.15384615384615385),
#   ('спасибо', 0.07692307692307693),
#   ('недаром', 0.07692307692307693),
#   ('сразу', 0.07692307692307693),
#   ('стало', 0.07692307692307693),
#   ('так', 0.07692307692307693),
#   ('японец', 0.07692307692307693),
#   ('сноусторм', 0.07692307692307693),
#   ('в', 0.07692307692307693)],
#  ('игре', 'за'): [('почти', 1.0)],
#  ('за', 'почти'): [('двадцать', 1.0)],
#  ('почти', 'двадцать'): [('лет', 1.0)],
#  ('двадцать', 'лет'): [('398-й', 0.25),
#   ('с', 0.25),
#   ('игре', 0.25),
#   ('двадцать', 0.25)],
#  ('лет', '398-й'): [('причем', 1.0)],
#  ('398-й', 'причем'): [('в', 1.0)],
#  ('причем', 'в'): [('дисгардиуме', 0.3333333333333333),
#   ('контрастном', 0.3333333333333333),
#   ('этом', 0.3333333333333333)],
#  ('в', 'дисгардиуме'): [('существуют', 0.06666666666666667),
#   ('политику', 0.06666666666666667),
#   ('хайро', 0.06666666666666667),
#   ('в', 0.13333333333333333),
#   ('долгой', 0.06666666666666667),
#   ('да', 0.06666666666666667),
#   ('а', 0.06666666666666667),
#   ('еще', 0.06666666666666667),
#   ('достигли', 0.13333333333333333),
#   ('айлин', 0.06666666666666667),
#   ('часом', 0.06666666666666667),
#   ('апнулся', 0.06666666666666667),
#   ('лишь', 0.06666666666666667)],
#  ('дисгардиуме', 'существуют'): [('зоны', 1.0)],
#  ('существуют', 'зоны'): [('для', 1.0)],
#  ('зоны', 'для'): [('уровней', 1.0)],
#  ('для', 'уровней'): [('1', 1.0)],
#  ('уровней', '1'): [('000', 1.0)],
#  ('1', '000'): [('даже', 0.1),
#   ('000', 0.6),
#   ('очков', 0.1),
#   ('интеллект', 0.1),
#   ('текущая', 0.1)],
#  ('000', 'даже'): [('логистика', 1.0)],
#  ('даже', 'логистика'): [('в', 1.0)],
#  ('логистика', 'в'): [('игре', 1.0)],
#  ('игре', 'приближена'): [('к', 1.0)],
#  ('приближена', 'к'): [('реалу', 1.0)],
#  ('к', 'реалу'): [('до', 1.0)],
#  ('реалу', 'до'): [('неоткрытых', 1.0)],
#  ('до', 'неоткрытых'): [('континентов', 1.0)],
#  ('неоткрытых', 'континентов'): [('с', 1.0)],
#  ('континентов', 'с'): [('текущими', 1.0)],
#  ('с', 'текущими'): [('максимальными', 1.0)],
#  ('текущими', 'максимальными'): [('уровнями', 1.0)],
#  ('максимальными', 'уровнями'): [('просто', 1.0)],
#  ('уровнями', 'просто'): [('не', 1.0)],
#  ('просто', 'не'): [('добраться', 0.07692307692307693),
#   ('выдержал', 0.07692307692307693),
#   ('увидел', 0.07692307692307693),
#   ('может', 0.07692307692307693),
#   ('рыпайся', 0.07692307692307693),
#   ('посчитали', 0.07692307692307693),
#   ('запустится', 0.07692307692307693),
#   ('обращали', 0.15384615384615385),
#   ('получил', 0.07692307692307693),
#   ('можем', 0.07692307692307693),
#   ('уйдут', 0.07692307692307693),
#   ('успел', 0.07692307692307693)],
#  ('не', 'добраться'): [('из-за', 1.0)],
#  ('добраться', 'из-за'): [('враждебной', 1.0)],
#  ('из-за', 'враждебной'): [('морской', 1.0)],
#  ('враждебной', 'морской'): [('фауны', 1.0)],
#  ('морской', 'фауны'): [('погодных', 1.0)],
#  ('фауны', 'погодных'): [('катаклизмов', 1.0)],
#  ('погодных', 'катаклизмов'): [('и', 1.0)],
#  ('катаклизмов', 'и'): [('скорости', 1.0)],
#  ('и', 'скорости'): [('передвижения', 1.0)],
#  ('скорости', 'передвижения'): [('парусников', 0.25),
#   ('утроилась', 0.25),
#   ('в', 0.25),
#   ('296', 0.25)],
#  ('передвижения', 'парусников'): [('каждый', 1.0)],
#  ('парусников', 'каждый'): [('разумный', 1.0)],
#  ('каждый', 'разумный'): [('моб', 1.0)],
#  ('разумный', 'моб'): [('и', 1.0)],
#  ('моб', 'и'): [('управляется', 1.0)],
#  ('и', 'управляется'): [('собственным', 1.0)],
#  ('управляется', 'собственным'): [('искином', 1.0)],
#  ('собственным', 'искином'): [('с', 1.0)],
#  ('искином', 'с'): [('заложенными', 1.0)],
#  ('с', 'заложенными'): [('целями', 1.0)],
#  ('заложенными', 'целями'): [('выживание', 1.0)],
#  ('целями', 'выживание'): [('развитие', 1.0)],
#  ('выживание', 'развитие'): [('продолжение', 1.0)],
#  ('развитие', 'продолжение'): [('рода', 1.0)],
#  ('продолжение', 'рода'): [('экосистема', 1.0)],
#  ('рода', 'экосистема'): [('и', 1.0)],
#  ('экосистема', 'и'): [('пищевая', 1.0)],
#  ('и', 'пищевая'): [('пирамида', 1.0)],
#  ('пищевая', 'пирамида'): [('строго', 1.0)],
#  ('пирамида', 'строго'): [('выверены', 1.0)],
#  ('строго', 'выверены'): [('и', 1.0)],
#  ('выверены', 'и'): [('соблюдены', 1.0)],
#  ('и', 'соблюдены'): [('архитекторами', 1.0)],
#  ('соблюдены', 'архитекторами'): [('баланс', 1.0)],
#  ('архитекторами', 'баланс'): [('мира', 1.0)],
#  ('баланс', 'мира'): [('краеугольный', 1.0)],
#  ('мира', 'краеугольный'): [('камень', 1.0)],
#  ('краеугольный', 'камень'): [('заложенный', 1.0)],
#  ('камень', 'заложенный'): [('основателями', 1.0)],
#  ('заложенный', 'основателями'): [('по', 1.0)],
#  ('основателями', 'по'): [('задумке', 1.0)],
#  ('по', 'задумке'): [('создателей', 1.0)],
#  ('задумке', 'создателей'): [('после', 1.0)],
#  ('создателей', 'после'): [('запуска', 1.0)],
#  ('после', 'запуска'): [('игры', 0.5), ('скорее', 0.5)],
#  ('запуска', 'игры'): [('в', 1.0)],
#  ('игры', 'в'): [('нее', 1.0)],
#  ('в', 'нее'): [('нельзя', 0.3333333333333333),
#   ('но', 0.3333333333333333),
#   ('зубами', 0.3333333333333333)],
#  ('нее', 'нельзя'): [('внести', 1.0)],
#  ('нельзя', 'внести'): [('никаких', 1.0)],
#  ('внести', 'никаких'): [('изменений', 1.0)],
#  ('никаких', 'изменений'): [('ядро', 1.0)],
#  ('изменений', 'ядро'): [('всегда', 1.0)],
#  ('ядро', 'всегда'): [('остается', 1.0)],
#  ('всегда', 'остается'): [('одним', 1.0)],
#  ('остается', 'одним'): [('и', 1.0)],
#  ('одним', 'и'): [('тем', 1.0)],
#  ('и', 'тем'): [('же', 0.3333333333333333),
#   ('усилить', 0.3333333333333333),
#   ('что', 0.3333333333333333)],
#  ('тем', 'же'): [('а', 0.125),
#   ('подавителем', 0.125),
#   ('днем', 0.125),
#   ('акулам', 0.125),
#   ('шаром', 0.125),
#   ('и', 0.125),
#   ('самым', 0.25)],
#  ('же', 'а'): [('многочисленные', 1.0)],
#  ('а', 'многочисленные'): [('бывшие', 1.0)],
#  ('многочисленные', 'бывшие'): [('настоящие', 1.0)],
#  ('бывшие', 'настоящие'): [('и', 1.0)],
#  ('настоящие', 'и'): [('будущие', 1.0)],
#  ('и', 'будущие'): [('игровые', 0.5), ('планы', 0.5)],
#  ('будущие', 'игровые'): [('события', 1.0)],
#  ('игровые', 'события'): [('происходят', 1.0)],
#  ('события', 'происходят'): [('сами', 1.0)],
#  ('происходят', 'сами'): [('естественным', 1.0)],
#  ('сами', 'естественным'): [('путем', 1.0)],
#  ('естественным', 'путем'): [('или', 1.0)],
#  ('путем', 'или'): [('от', 1.0)],
#  ('или', 'от'): [('срабатывания', 0.5), ('усталости', 0.5)],
#  ('от', 'срабатывания'): [('какого-либо', 1.0)],
#  ('срабатывания', 'какого-либо'): [('игрового', 1.0)],
#  ('какого-либо', 'игрового'): [('триггера', 1.0)],
#  ('игрового', 'триггера'): [('для', 1.0)],
#  ('триггера', 'для'): [('сохранения', 1.0)],
#  ('для', 'сохранения'): [('баланса', 1.0)],
#  ('сохранения', 'баланса'): [('сноусторм', 1.0)],
#  ('баланса', 'сноусторм'): [('вводит', 1.0)],
#  ('сноусторм', 'вводит'): [('в', 1.0)],
#  ('вводит', 'в'): [('дисгардиуме', 1.0)],
#  ('дисгардиуме', 'политику'): [('угроз', 1.0)],
#  ('политику', 'угроз'): [('чтобы', 1.0)],
#  ('угроз', 'чтобы'): [('игровыми', 1.0)],
#  ('чтобы', 'игровыми'): [('методами', 1.0)],
#  ('игровыми', 'методами'): [('выбивать', 1.0)],
#  ('методами', 'выбивать'): [('несбалансированных', 1.0)],
#  ('выбивать', 'несбалансированных'): [('персонажей', 1.0)],
#  ('несбалансированных', 'персонажей'): [('такие', 1.0)],
#  ('персонажей', 'такие'): [('игроки', 1.0)],
#  ('такие', 'игроки'): [('объявляются', 1.0)],
#  ('игроки', 'объявляются'): [('угрозами', 1.0)],
#  ('объявляются', 'угрозами'): [('любого', 1.0)],
#  ('угрозами', 'любого'): [('игрока-угрозу', 1.0)],
#  ('любого', 'игрока-угрозу'): [('идентифицированного', 1.0)],
#  ('игрока-угрозу', 'идентифицированного'): [('артефактом', 1.0)],
#  ('идентифицированного', 'артефактом'): [('истинного', 1.0)],
#  ('артефактом', 'истинного'): [('пламени', 1.0)],
#  ('истинного', 'пламени'): [('можно', 0.2),
#   ('также', 0.2),
#   ('а', 0.2),
#   ('были', 0.2),
#   ('следом', 0.2)],
#  ('пламени', 'можно'): [('навсегда', 1.0)],
#  ('можно', 'навсегда'): [('выкинуть', 1.0)],
#  ('навсегда', 'выкинуть'): [('из', 1.0)],
#  ('выкинуть', 'из'): [('игры', 1.0)],
#  ('из', 'игры'): [('проведя', 0.25),
#   ('только', 0.25),
#   ('если', 0.25),
#   ('чтобы', 0.25)],
#  ('игры', 'проведя'): [('несложный', 1.0)],
#  ('проведя', 'несложный'): [('ритуал', 1.0)],
#  ('несложный', 'ритуал'): [('ликвидатор', 1.0)],
#  ('ритуал', 'ликвидатор'): [('получает', 1.0)],
#  ('ликвидатор', 'получает'): [('награды', 1.0)],
#  ('получает', 'награды'): [('соответствующие', 1.0)],
#  ('награды', 'соответствующие'): [('потенциалу', 1.0)],
#  ('соответствующие', 'потенциалу'): [('угрозы', 1.0)],
#  ('потенциалу', 'угрозы'): [('сама', 1.0)],
#  ('угрозы', 'сама'): [('угроза', 1.0)],
#  ('сама', 'угроза'): [('тоже', 0.5), ('побоялась', 0.5)],
#  ('угроза', 'тоже'): [('награждается', 0.5), ('требует', 0.5)],
#  ('тоже', 'награждается'): [('чем', 1.0)],
#  ('награждается', 'чем'): [('выше', 1.0)],
#  ('чем', 'выше'): [('ее', 1.0)],
#  ('выше', 'ее'): [('класс', 1.0)],
#  ('ее', 'класс'): [('тем', 1.0)],
#  ('класс', 'тем'): [('больше', 1.0)],
#  ('тем', 'больше'): [('компенсация', 0.25), ('веры', 0.25), ('шансов', 0.5)],
#  ('больше', 'компенсация'): [('но', 1.0)],
#  ('компенсация', 'но'): [('тем', 1.0)],
#  ('но', 'тем'): [('труднее', 0.5), ('приятнее', 0.5)],
#  ('тем', 'труднее'): [('ее', 1.0)],
#  ('труднее', 'ее'): [('устранить', 1.0)],
#  ('ее', 'устранить'): [('если', 1.0)],
#  ('устранить', 'если'): [('статус', 1.0)],
#  ('если', 'статус'): [('мощной', 1.0)],
#  ('статус', 'мощной'): [('угрозы', 1.0)],
#  ('мощной', 'угрозы'): [('достигнет', 1.0)],
#  ('угрозы', 'достигнет'): [('предельных', 1.0)],
#  ('достигнет', 'предельных'): [('значений', 1.0)],
#  ('предельных', 'значений'): [('ликвидировать', 1.0)],
#  ('значений', 'ликвидировать'): [('ее', 1.0)],
#  ('ликвидировать', 'ее'): [('будет', 1.0)],
#  ('ее', 'будет'): [('практически', 1.0)],
#  ('будет', 'практически'): [('невозможно', 1.0)],
#  ('практически', 'невозможно'): [('таким', 1.0)],
#  ('невозможно', 'таким'): [('образом', 1.0)],
#  ('таким', 'образом'): [('ликвидаторам', 0.25),
#   ('чувствуешь', 0.25),
#   ('а', 0.25),
#   ('молится', 0.25)],
#  ('образом', 'ликвидаторам'): [('или', 1.0)],
#  ('ликвидаторам', 'или'): [('превентивам', 1.0)],
#  ('или', 'превентивам'): [('как', 1.0)],
#  ('превентивам', 'как'): [('они', 1.0)],
#  ('как', 'они'): [('себя', 0.2),
#   ('возвращаются', 0.2),
#   ('поймут', 0.2),
#   ('выразились', 0.2),
#   ('обустроились', 0.2)],
#  ('они', 'себя'): [('называют', 1.0)],
#  ('себя', 'называют'): [('выгоднее', 1.0)],
#  ('называют', 'выгоднее'): [('уничтожать', 1.0)],
#  ('выгоднее', 'уничтожать'): [('угрозы', 1.0)],
#  ('уничтожать', 'угрозы'): [('до', 1.0)],
#  ('угрозы', 'до'): [('того', 0.5), ('максимального', 0.5)],
#  ('до', 'того'): [('как', 0.5294117647058824),
#   ('да', 0.058823529411764705),
#   ('наказание', 0.058823529411764705),
#   ('из', 0.058823529411764705),
#   ('он', 0.058823529411764705),
#   ('пять', 0.058823529411764705),
#   ('молчавший', 0.058823529411764705),
#   ('смотревший', 0.058823529411764705),
#   ('что', 0.058823529411764705)],
#  ('того', 'как'): [('те', 0.05263157894736842),
#   ('спадет', 0.05263157894736842),
#   ('их', 0.05263157894736842),
#   ('мы', 0.10526315789473684),
#   ('с', 0.05263157894736842),
#   ('каким-то', 0.05263157894736842),
#   ('хищная', 0.05263157894736842),
#   ('слетали', 0.05263157894736842),
#   ('дэка', 0.05263157894736842),
#   ('погиб', 0.05263157894736842),
#   ('я', 0.10526315789473684),
#   ('все', 0.05263157894736842),
#   ('раскошелились', 0.05263157894736842),
#   ('айлин', 0.05263157894736842),
#   ('смоляные', 0.05263157894736842),
#   ('союзники', 0.05263157894736842),
#   ('меня', 0.05263157894736842)],
#  ('как', 'те'): [('усилятся', 1.0)],
#  ('те', 'усилятся'): [('самим', 1.0)],
#  ('усилятся', 'самим'): [('же', 1.0)],
#  ('самим', 'же'): [('угрозам', 1.0)],
#  ('же', 'угрозам'): [('важно', 1.0)],
#  ('угрозам', 'важно'): [('скрываться', 1.0)],
#  ('важно', 'скрываться'): [('и', 1.0)],
#  ('скрываться', 'и'): [('развиваться', 1.0)],
#  ('и', 'развиваться'): [('их', 1.0)],
#  ('развиваться', 'их'): [('награда', 1.0)],
#  ('их', 'награда'): [('после', 1.0)],
#  ('награда', 'после'): [('ликвидации', 1.0)],
#  ('после', 'ликвидации'): [('высчитывается', 1.0)],
#  ('ликвидации', 'высчитывается'): [('не', 1.0)],
#  ('высчитывается', 'не'): [('от', 1.0)],
#  ('не', 'от'): [('потенциала', 0.5), ('риты', 0.5)],
#  ('от', 'потенциала'): [('а', 1.0)],
#  ('потенциала', 'а'): [('от', 1.0)],
#  ('а', 'от'): [('текущего', 0.25),
#   ('супермаркета', 0.25),
#   ('ядерных', 0.25),
#   ('нас', 0.25)],
#  ('от', 'текущего'): [('уровня', 1.0)],
#  ('текущего', 'уровня'): [('развития', 0.5), ('это', 0.5)],
#  ('уровня', 'развития'): [('статуса', 1.0)],
#  ('развития', 'статуса'): [('где', 1.0)],
#  ('статуса', 'где'): [('максимальный', 1.0)],
#  ('где', 'максимальный'): [('а', 1.0)],
#  ('максимальный', 'а'): [('минимальный', 1.0)],
#  ('а', 'минимальный'): [('к', 1.0)],
#  ('минимальный', 'к'): [('концу', 1.0)],
#  ('к', 'концу'): [('2074', 0.16666666666666666),
#   ('пути', 0.16666666666666666),
#   ('второго', 0.16666666666666666),
#   ('разговора', 0.16666666666666666),
#   ('без', 0.16666666666666666),
#   ('боя', 0.16666666666666666)],
#  ('концу', '2074'): [('года', 1.0)],
#  ('2074', 'года'): [('за', 1.0)],
#  ('года', 'за'): [('почти', 1.0)],
#  ('лет', 'с'): [('запуска', 1.0)],
#  ('с', 'запуска'): [('дисгардиума', 1.0)],
#  ('запуска', 'дисгардиума'): [('мир', 1.0)],
#  ('дисгардиума', 'мир'): [('так', 1.0)],
#  ('мир', 'так'): [('и', 1.0)],
#  ('так', 'и'): [('не', 0.5333333333333333),
#   ('в', 0.044444444444444446),
#   ('провисел', 0.022222222222222223),
#   ('есть', 0.06666666666666667),
#   ('остался', 0.044444444444444446),
#   ('сделал', 0.06666666666666667),
#   ('было', 0.022222222222222223),
#   ('лежал', 0.022222222222222223),
#   ('сейчас', 0.022222222222222223),
#   ('среди', 0.022222222222222223),
#   ('будешь', 0.022222222222222223),
#   ('думал', 0.022222222222222223),
#   ('погиб', 0.022222222222222223),
#   ('зависла', 0.022222222222222223),
#   ('осталось', 0.022222222222222223),
#   ('ее', 0.022222222222222223)],
#  ('и', 'не'): [('увидел', 0.00980392156862745),
#   ('дать', 0.00980392156862745),
#   ('отпуская', 0.00980392156862745),
#   ('отвел', 0.00980392156862745),
#   ('помнил', 0.00980392156862745),
#   ('один', 0.00980392156862745),
#   ('успевшими', 0.00980392156862745),
#   ('заметил', 0.00980392156862745),
#   ('устраивать', 0.00980392156862745),
#   ('успели', 0.00980392156862745),
#   ('особо', 0.00980392156862745),
#   ('сможем', 0.00980392156862745),
#   ('было', 0.0392156862745098),
#   ('дало', 0.00980392156862745),
#   ('обнаружил', 0.00980392156862745),
#   ('нашел', 0.0196078431372549),
#   ('сумев', 0.00980392156862745),
#   ('режь', 0.00980392156862745),
#   ('поняла', 0.00980392156862745),
#   ('таились', 0.00980392156862745),
#   ('думаю', 0.00980392156862745),
#   ('понял', 0.0392156862745098),
#   ('дошли', 0.00980392156862745),
#   ('давала', 0.00980392156862745),
#   ('удалось', 0.0196078431372549),
#   ('только', 0.00980392156862745),
#   ('добудившись', 0.00980392156862745),
#   ('вини', 0.00980392156862745),
#   ('смогла', 0.00980392156862745),
#   ('выпущу', 0.00980392156862745),
#   ('выпустит', 0.00980392156862745),
#   ('портить', 0.00980392156862745),
#   ('вернулись', 0.00980392156862745),
#   ('сгинул', 0.00980392156862745),
#   ('идентифицированные', 0.00980392156862745),
#   ('надо', 0.00980392156862745),
#   ('мог', 0.00980392156862745),
#   ('гному', 0.00980392156862745),
#   ('погнушался', 0.00980392156862745),
#   ('спрашивайте', 0.00980392156862745),
#   ('разгадал', 0.00980392156862745),
#   ('получал', 0.00980392156862745),
#   ('змеелюдей', 0.00980392156862745),
#   ('дающий', 0.00980392156862745),
#   ('видят', 0.00980392156862745),
#   ('нужно', 0.00980392156862745),
#   ('раз', 0.0196078431372549),
#   ('пообщался', 0.00980392156862745),
#   ('растерявшись', 0.00980392156862745),
#   ('будет', 0.00980392156862745),
#   ('такого', 0.00980392156862745),
#   ('чувствовал', 0.00980392156862745),
#   ('забудь', 0.00980392156862745),
#   ('споря', 0.00980392156862745),
# ...
#  ('треть', 'неграждане'): [('люди', 1.0)],
#  ('неграждане', 'люди'): [('признанные', 1.0)],
#  ('люди', 'признанные'): [('бесполезными', 1.0)],
#  ('признанные', 'бесполезными'): [('для', 1.0)],
#  ('бесполезными', 'для'): [('общества', 1.0)],
#  ('общества', 'а'): [('значит', 0.5), ('низший', 0.5)],
#  ('а', 'значит'): [('не', 0.0625),
#   ('и', 0.25),
#   ('причина', 0.0625),
#   ('правильнее', 0.0625),
#   ('есть', 0.0625),
#   ('для', 0.0625),
#   ('где-то', 0.0625),
#   ('без', 0.0625),
#   ('штурмом', 0.0625),
#   ('показаться', 0.0625),
#   ('потенциально', 0.0625),
#   ('будучи', 0.0625),
#   ('мы', 0.0625)],
#  ('значит', 'не'): [('имеющими', 0.5), ('видят', 0.5)],
#  ('не', 'имеющими'): [('прав', 1.0)],
#  ('имеющими', 'прав'): [('на', 1.0)],
#  ('прав', 'на'): [('блага', 1.0)],
#  ('на', 'блага'): [('цивилизации', 1.0)],
#  ('блага', 'цивилизации'): [('граждане', 1.0)],
#  ('цивилизации', 'граждане'): [('разделены', 1.0)],
#  ('граждане', 'разделены'): [('на', 1.0)],
#  ('разделены', 'на'): [('двенадцать', 1.0)],
#  ('на', 'двенадцать'): [('категорий', 0.3333333333333333),
#   ('часов', 0.6666666666666666)],
#  ('двенадцать', 'категорий'): [('где', 1.0)],
#  ('категорий', 'где'): [('а', 1.0)],
#  ('где', 'а'): [('наивысший', 1.0)],
#  ('а', 'наивысший'): [('статус', 1.0)],
#  ('наивысший', 'статус'): [('элита', 1.0)],
#  ('статус', 'элита'): [('общества', 1.0)],
#  ('элита', 'общества'): [('а', 1.0)],
#  ('а', 'низший'): [('согласно', 1.0)],
#  ('низший', 'согласно'): [('рекомендациям', 1.0)],
#  ('согласно', 'рекомендациям'): [('департамента', 1.0)],
#  ('рекомендациям', 'департамента'): [('образования', 1.0)],
#  ('департамента', 'образования'): [('оон', 1.0)],
#  ('образования', 'оон'): [('каждый', 1.0)],
#  ('оон', 'каждый'): [('подросток', 1.0)],
#  ('каждый', 'подросток'): [('с', 1.0)],
#  ('подросток', 'с'): [('четырнадцати', 1.0)],
#  ('с', 'четырнадцати'): [('до', 1.0)],
#  ('четырнадцати', 'до'): [('шестнадцати', 1.0)],
#  ('до', 'шестнадцати'): [('лет', 0.5), ('секунд', 0.5)],
#  ('шестнадцати', 'лет'): [('должен', 1.0)],
#  ('лет', 'должен'): [('проводить', 1.0)],
#  ('должен', 'проводить'): [('в', 1.0)],
#  ('проводить', 'в'): [('игре', 1.0)],
#  ('игре', 'дисгардиум'): [('час', 1.0)],
#  ('дисгардиум', 'час'): [('в', 1.0)],
#  ('час', 'в'): [('день', 0.3333333333333333),
#   ('междумирье', 0.3333333333333333),
#   ('реале', 0.3333333333333333)],
#  ('в', 'день'): [('считается', 0.5), ('нашего', 0.5)],
#  ('день', 'считается'): [('что', 1.0)],
#  ('считается', 'что'): [('эта', 0.5), ('если', 0.5)],
#  ('что', 'эта'): [('важная', 1.0)],
#  ('эта', 'важная'): [('часть', 1.0)],
#  ('важная', 'часть'): [('воспитания', 1.0)],
#  ('часть', 'воспитания'): [('даст', 1.0)],
#  ('воспитания', 'даст'): [('подростку', 1.0)],
#  ('даст', 'подростку'): [('необходимые', 1.0)],
#  ('подростку', 'необходимые'): [('навыки', 1.0)],
#  ('необходимые', 'навыки'): [('социализации', 1.0)],
#  ('навыки', 'социализации'): [('и', 1.0)],
#  ('социализации', 'и'): [('подготовит', 1.0)],
#  ('и', 'подготовит'): [('ко', 1.0)],
#  ('подготовит', 'ко'): [('взрослой', 1.0)],
#  ('ко', 'взрослой'): [('жизни', 1.0)],
#  ('взрослой', 'жизни'): [('школьник', 1.0)],
#  ('жизни', 'школьник'): [('алекс', 1.0)],
#  ('школьник', 'алекс'): [('шеппард', 1.0)],
#  ('алекс', 'шеппард'): [('при', 0.2),
#   ('третий', 0.2),
#   ('десятый', 0.2),
#   ('пай-мальчик', 0.2),
#   ('скрыто', 0.2)],
#  ('шеппард', 'при'): [('регистрации', 1.0)],
#  ('при', 'регистрации'): [('берет', 1.0)],
#  ('регистрации', 'берет'): [('себе', 1.0)],
#  ('берет', 'себе'): [('игровое', 1.0)],
#  ('себе', 'игровое'): [('имя', 1.0)],
#  ('игровое', 'имя'): [('скиф', 1.0)],
#  ('имя', 'скиф'): [('неверно', 1.0)],
#  ('скиф', 'неверно'): [('создав', 1.0)],
#  ('неверно', 'создав'): [('персонажа', 1.0)],
#  ('создав', 'персонажа'): [('и', 1.0)],
#  ('персонажа', 'и'): [('столкнувшись', 0.25),
#   ('прогресс', 0.25),
#   ('его', 0.25),
#   ('объявлю', 0.25)],
#  ('и', 'столкнувшись'): [('со', 1.0)],
#  ('столкнувшись', 'со'): [('сложностями', 1.0)],
#  ('со', 'сложностями'): [('он', 1.0)],
#  ('сложностями', 'он'): [('быстро', 1.0)],
#  ('он', 'быстро'): [('теряет', 0.5), ('зачитал', 0.5)],
#  ('быстро', 'теряет'): [('интерес', 1.0)],
#  ('теряет', 'интерес'): [('к', 1.0)],
#  ('интерес', 'к'): [('игре', 0.3333333333333333),
#   ('тому', 0.3333333333333333),
#   ('жизни', 0.3333333333333333)],
#  ('к', 'игре'): [('и', 1.0)],
#  ('игре', 'и'): [('больше', 1.0)],
#  ('и', 'больше'): [('года', 0.5), ('не', 0.5)],
#  ('больше', 'года'): [('проводит', 1.0)],
#  ('года', 'проводит'): [('обязательные', 1.0)],
#  ('проводит', 'обязательные'): [('часы', 1.0)],
#  ('обязательные', 'часы'): [('в', 1.0)],
#  ('часы', 'в'): [('песочнице', 1.0)],
#  ('в', 'песочнице'): [('сидя', 0.1),
#   ('хотел', 0.1),
#   ('грузчиков', 0.1),
#   ('еще', 0.1),
#   ('лишь', 0.1),
#   ('фильтровалось', 0.1),
#   ('но', 0.1),
#   ('когда', 0.1),
#   ('нам', 0.1),
#   ('кроме', 0.1)],
#  ('песочнице', 'сидя'): [('на', 1.0)],
#  ('сидя', 'на'): [('лавочке', 1.0)],
#  ('на', 'лавочке'): [('у', 1.0)],
#  ('лавочке', 'у'): [('таверны', 1.0)],
#  ('у', 'таверны'): [('его', 0.5), ('привет', 0.5)],
#  ('таверны', 'его'): [('родители', 1.0)],
#  ('его', 'родители'): [('собираются', 0.5), ('провалили', 0.5)],
#  ('родители', 'собираются'): [('развестись', 1.0)],
#  ('собираются', 'развестись'): [('из-за', 1.0)],
#  ('развестись', 'из-за'): [('чего', 1.0)],
#  ('из-за', 'чего'): [('снизится', 0.16666666666666666),
#   ('скиф', 0.16666666666666666),
#   ('форт', 0.16666666666666666),
#   ('он', 0.3333333333333333),
#   ('не', 0.16666666666666666)],
#  ('чего', 'снизится'): [('их', 1.0)],
#  ('снизится', 'их'): [('гражданский', 1.0)],
#  ('их', 'гражданский'): [('статус', 1.0)],
#  ('гражданский', 'статус'): [('уменьшатся', 0.25),
#   ('друзья', 0.25),
#   ('и', 0.25),
#   ('присваивался', 0.25)],
#  ('статус', 'уменьшатся'): [('доходы', 1.0)],
#  ('уменьшатся', 'доходы'): [('и', 1.0)],
#  ('доходы', 'и'): [('они', 1.0)],
#  ('и', 'они'): [('не', 0.16666666666666666),
#   ('сагрятся', 0.16666666666666666),
#   ('побоялись', 0.16666666666666666),
#   ('могли', 0.16666666666666666),
#   ('и', 0.16666666666666666),
#   ('это', 0.16666666666666666)],
#  ('они', 'не'): [('смогут', 0.16666666666666666),
#   ('спешили', 0.08333333333333333),
#   ('двигались', 0.08333333333333333),
#   ('дождутся', 0.08333333333333333),
#   ('успевают', 0.08333333333333333),
#   ('занимали', 0.08333333333333333),
#   ('могут', 0.16666666666666666),
#   ('лезут', 0.08333333333333333),
#   ('требуют', 0.08333333333333333),
#   ('только', 0.08333333333333333)],
#  ('не', 'смогут'): [('оплатить', 0.3333333333333333),
#   ('пока', 0.3333333333333333),
#   ('вырвать', 0.3333333333333333)],
#  ('смогут', 'оплатить'): [('образование', 1.0)],
#  ('оплатить', 'образование'): [('алекса', 1.0)],
#  ('образование', 'алекса'): [('который', 1.0)],
#  ('алекса', 'который'): [('мечтает', 1.0)],
#  ('который', 'мечтает'): [('стать', 1.0)],
#  ('мечтает', 'стать'): [('космическим', 1.0)],
#  ('стать', 'космическим'): [('гидом', 1.0)],
#  ('космическим', 'гидом'): [('начата', 1.0)],
#  ('гидом', 'начата'): [('колонизация', 1.0)],
#  ('начата', 'колонизация'): [('марса', 1.0)],
#  ('колонизация', 'марса'): [('разрабатываются', 1.0)],
#  ('марса', 'разрабатываются'): [('планы', 1.0)],
#  ('разрабатываются', 'планы'): [('по', 1.0)],
#  ('планы', 'по'): [('смещению', 0.5), ('клановой', 0.5)],
#  ('по', 'смещению'): [('с', 1.0)],
#  ('смещению', 'с'): [('орбиты', 1.0)],
#  ('с', 'орбиты'): [('венеры', 1.0)],
#  ('орбиты', 'венеры'): [('за', 1.0)],
#  ('венеры', 'за'): [('полгода', 1.0)],
#  ('за', 'полгода'): [('до', 0.5), ('ага', 0.5)],
#  ('полгода', 'до'): [('окончания', 1.0)],
#  ('до', 'окончания'): [('школы', 0.25),
#   ('службы', 0.25),
#   ('светового', 0.25),
#   ('ивента', 0.25)],
#  ('окончания', 'школы'): [('алекс', 1.0)],
#  ('школы', 'алекс'): [('вынужден', 1.0)],
#  ('алекс', 'вынужден'): [('начать', 1.0)],
#  ('вынужден', 'начать'): [('играть', 1.0)],
#  ('начать', 'играть'): [('в', 0.5), ('на', 0.5)],
#  ('играть', 'в'): [('дисгардиум', 0.5), ('свою', 0.5)],
#  ('в', 'дисгардиум'): [('по-настоящему', 0.25),
#   ('до', 0.25),
#   ('дейли', 0.25),
#   ('спящий', 0.25)],
#  ('дисгардиум', 'по-настоящему'): [('ему', 1.0)],
#  ('по-настоящему', 'ему'): [('нужно', 1.0)],
#  ('ему', 'нужно'): [('заработать', 0.3333333333333333),
#   ('изучить', 0.3333333333333333),
#   ('узнал', 0.3333333333333333)],
#  ('нужно', 'заработать'): [('на', 1.0)],
#  ('заработать', 'на'): [('оплату', 1.0)],
#  ('на', 'оплату'): [('обучения', 1.0)],
#  ('оплату', 'обучения'): [('алекс-скиф', 1.0)],
#  ('обучения', 'алекс-скиф'): [('становится', 1.0)],
#  ('алекс-скиф', 'становится'): [('угрозой', 1.0)],
#  ('становится', 'угрозой'): [('с', 0.6666666666666666),
#   ('вернувшийся', 0.3333333333333333)],
#  ('угрозой', 'с'): [('потенциалом', 1.0)],
#  ('с', 'потенциалом'): [('из-за', 0.3333333333333333),
#   ('но', 0.3333333333333333),
#   ('скрытый', 0.3333333333333333)],
#  ('потенциалом', 'из-за'): [('нескольких', 1.0)],
#  ('из-за', 'нескольких'): [('маловероятных', 1.0)],
#  ('нескольких', 'маловероятных'): [('событий', 1.0)],
#  ('маловероятных', 'событий'): [('произошедших', 1.0)],
#  ('событий', 'произошедших'): [('одновременно', 1.0)],
#  ('произошедших', 'одновременно'): [('его', 1.0)],
#  ('одновременно', 'его'): [('проклинает', 1.0)],
#  ('его', 'проклинает'): [('патрик', 1.0)],
#  ('проклинает', 'патрик'): [('о', 1.0)],
#  ('патрик', 'о'): [('грейди', 1.0)],
#  ('о', 'грейди'): [('тем', 0.06666666666666667),
#   ('мэнни', 0.06666666666666667),
#   ('свитки', 0.06666666666666667),
#   ('я', 0.06666666666666667),
#   ('который', 0.06666666666666667),
#   ('они', 0.06666666666666667),
#   ('кобольды', 0.06666666666666667),
#   ('на', 0.06666666666666667),
#   ('ветераном', 0.06666666666666667),
#   ('первый', 0.06666666666666667),
#   ('повысится', 0.06666666666666667),
#   ('его', 0.06666666666666667),
#   ('снова', 0.06666666666666667),
#   ('и', 0.06666666666666667),
#   ('канализационные', 0.06666666666666667)],
#  ('грейди', 'тем'): [('самым', 1.0)],
#  ('тем', 'самым'): [('заставляя', 0.2),
#   ('парнем', 0.2),
#   ('что', 0.2),
#   ('разбив', 0.2),
#   ('создавая', 0.2)],
#  ('самым', 'заставляя'): [('возрождаться', 1.0)],
#  ('заставляя', 'возрождаться'): [('на', 1.0)],
#  ('возрождаться', 'на'): [('месте', 1.0)],
#  ('на', 'месте'): [('смерти', 0.07142857142857142),
#   ('падения', 0.14285714285714285),
#   ('я', 0.07142857142857142),
#   ('всеми', 0.07142857142857142),
#   ('набрав', 0.07142857142857142),
#   ('погодные', 0.07142857142857142),
#   ('не', 0.07142857142857142),
#   ('он', 0.07142857142857142),
#   ('переместить', 0.07142857142857142),
#   ('властей', 0.07142857142857142),
#   ('глаз', 0.07142857142857142),
#   ('головы', 0.07142857142857142),
#   ('в', 0.07142857142857142)],
#  ('месте', 'смерти'): [('а', 1.0)],
#  ('смерти', 'а'): [('другой', 0.5), ('значит', 0.5)],
#  ('а', 'другой'): [('-лич', 1.0)],
#  ('другой', '-лич'): [('босс', 1.0)],
#  ('-лич', 'босс'): [('подземелья', 1.0)],
#  ('босс', 'подземелья'): [('как', 1.0)],
#  ('подземелья', 'как'): [('оказывается', 1.0)],
#  ('как', 'оказывается'): [('отыгрывается', 1.0)],
#  ('оказывается', 'отыгрывается'): [('человеком-негражданином', 1.0)],
#  ('отыгрывается', 'человеком-негражданином'): [('андреем', 1.0)],
#  ('человеком-негражданином', 'андреем'): [('клейтоном', 1.0)],
#  ('андреем', 'клейтоном'): [('и', 1.0)],
#  ('клейтоном', 'и'): [('входит', 1.0)],
#  ('и', 'входит'): [('с', 1.0)],
#  ('входит', 'с'): [('алексом', 1.0)],
#  ('с', 'алексом'): [('в', 0.3333333333333333),
#   ('там', 0.3333333333333333),
#   ('шеппардом', 0.3333333333333333)],
#  ('алексом', 'в'): [('контакт', 1.0)],
#  ('в', 'контакт'): [('клейтон', 1.0)],
#  ('контакт', 'клейтон'): [('был', 1.0)],
#  ('клейтон', 'был'): [('пилотом', 1.0)],
#  ('был', 'пилотом'): [('космического', 1.0)],
#  ('пилотом', 'космического'): [('грузового', 1.0)],
#  ('космического', 'грузового'): [('шаттла', 1.0)],
#  ('грузового', 'шаттла'): [('и', 1.0)],
#  ('шаттла', 'и'): [('после', 1.0)],
#  ('и', 'после'): [('аварии', 0.3333333333333333),
#   ('контрастного', 0.3333333333333333),
#   ('благословения', 0.3333333333333333)],
#  ('после', 'аварии'): [('лишился', 1.0)],
#  ('аварии', 'лишился'): [('гражданства', 1.0)],
#  ('лишился', 'гражданства'): [('видя', 1.0)],
#  ('гражданства', 'видя'): [('упорство', 1.0)],
#  ('видя', 'упорство'): [('скифа', 1.0)],
#  ('упорство', 'скифа'): [('раз', 1.0)],
#  ('скифа', 'раз'): [('за', 1.0)],
#  ('раз', 'за'): [('разом', 0.25),
#   ('день', 0.375),
#   ('полный', 0.125),
#   ('сегодня', 0.125),
#   ('сутки', 0.125)],
#  ('за', 'разом'): [('гибнущего', 0.5), ('пока', 0.5)],
#  ('разом', 'гибнущего'): [('но', 1.0)],
#  ('гибнущего', 'но'): [('не', 1.0)],
#  ('но', 'не'): [('сдающегося', 0.025),
#   ('вынесла', 0.025),
#   ('находил', 0.025),
#   ('исключено', 0.025),
#   ('чувствовал', 0.025),
#   ('сработал', 0.025),
#   ('сверхмощь', 0.025),
#   ('мы', 0.025),
#   ('свою', 0.025),
#   ('видя', 0.025),
#   ('о', 0.025),
#   ('сразу', 0.025),
#   ('могу', 0.025),
#   ('упуская', 0.025),
#   ('успел', 0.05),
#   ('настолько', 0.025),
#   ('придал', 0.025),
#   ('ниже', 0.025),
#   ('в', 0.05),
#   ('этого', 0.025),
#   ('сумел', 0.025),
#   ('собиралась', 0.025),
#   ('могли', 0.025),
#   ('для', 0.025),
#   ('плохо', 0.025),
#   ('сейчас', 0.025),
#   ('последний', 0.025),
#   ('дороже', 0.025),
#   ('ушел', 0.025),
#   ('меня', 0.025),
#   ('прикончить', 0.025),
#   ('пересекавших', 0.025),
#   ('переживайте', 0.025),
#   ('выделить', 0.025),
#   ('так', 0.025),
#   ('возрождайтесь', 0.025),
#   ('представлял', 0.025),
#   ('успевал', 0.025)],
#  ('не', 'сдающегося'): [('он', 1.0)],
#  ('сдающегося', 'он'): [('поддается', 1.0)],
#  ('он', 'поддается'): [('и', 1.0)],
#  ('поддается', 'и'): [('позволяет', 1.0)],
#  ('и', 'позволяет'): [('себя', 0.3333333333333333),
#   ('выбрать', 0.3333333333333333),
#   ('распределить', 0.3333333333333333)],
#  ('позволяет', 'себя'): [('убить', 1.0)],
#  ('себя', 'убить'): [('от', 1.0)],
#  ('убить', 'от'): [('погибшего', 1.0)],
#  ('от', 'погибшего'): [('окончательной', 1.0)],
#  ('погибшего', 'окончательной'): [('смертью', 1.0)],
#  ('окончательной', 'смертью'): [('финального', 0.25),
#   ('и', 0.25),
#   ('персонажа', 0.25),
#   ('акулон', 0.25)],
#  ('смертью', 'финального'): [('босса', 1.0)],
#  ('финального', 'босса'): [('скиф', 0.3333333333333333),
#   ('логова', 0.3333333333333333),
#   ('снежных', 0.3333333333333333)],
#  ('босса', 'скиф'): [('получает', 1.0)],
#  ('скиф', 'получает'): [('метку', 0.3333333333333333),
#   ('уникальный', 0.3333333333333333),
#   ('приглашение', 0.3333333333333333)],
#  ('получает', 'метку'): [('чумного', 1.0)],
#  ('метку', 'чумного'): [('мора', 1.0)],
#  ('мора', 'то'): [('есть', 1.0)],
#  ('то', 'есть'): [('возможность', 0.07142857142857142),
#   ('универсальной', 0.07142857142857142),
#   ('примерно', 0.07142857142857142),
#   ('головой-то', 0.07142857142857142),
#   ('должны', 0.07142857142857142),
#   ('почти', 0.07142857142857142),
#   ('с', 0.07142857142857142),
#   ('получается', 0.07142857142857142),
#   ('знала', 0.07142857142857142),
#   ('миллионами', 0.07142857142857142),
#   ('как', 0.07142857142857142),
#   ('я', 0.07142857142857142),
#   ('из', 0.07142857142857142),
#   ('они', 0.07142857142857142)],
#  ('есть', 'возможность'): [('переносить', 1.0)],
#  ('возможность', 'переносить'): [('любой', 1.0)],
#  ('переносить', 'любой'): [('урон', 1.0)],
#  ('любой', 'урон'): [('не', 0.3333333333333333), ('в', 0.6666666666666666)],
#  ('урон', 'не'): [('умирая', 0.3333333333333333),
#   ('прошел', 0.3333333333333333),
#   ('знаю', 0.3333333333333333)],
#  ('не', 'умирая'): [('вкупе', 1.0)],
#  ('умирая', 'вкупе'): [('с', 1.0)],
#  ('вкупе', 'с'): [('проклятием', 0.5), ('теми', 0.5)],
#  ('с', 'проклятием'): [('патрика', 1.0)],
#  ('проклятием', 'патрика'): [('это', 1.0)],
#  ('патрика', 'это'): [('позволяет', 1.0)],
#  ('это', 'позволяет'): [('ему', 0.5), ('решить', 0.5)],
#  ('позволяет', 'ему'): [('добраться', 1.0)],
#  ('ему', 'добраться'): [('до', 1.0)],
#  ('добраться', 'до'): [('необитаемой', 0.25),
#   ('храма', 0.25),
#   ('подводного', 0.25),
#   ('сердца', 0.25)],
#  ('до', 'необитаемой'): [('территории', 1.0)],
#  ('необитаемой', 'территории'): [('в', 1.0)],
#  ('территории', 'в'): [('болотине', 1.0)],
#  ('в', 'болотине'): [('где', 0.5), ('декотра', 0.5)],
#  ('болотине', 'где'): [('дремлет', 1.0)],
#  ('где', 'дремлет'): [('затухающий', 1.0)],
#  ('дремлет', 'затухающий'): [('аватар', 1.0)],
#  ('затухающий', 'аватар'): [('бегемота', 1.0)],
#  ('аватар', 'бегемота'): [('одного', 1.0)],
#  ...}

# %%
tuple(filter(lambda key: key[0] == prefix, model))
# Out:
# ()

# %%
numbers = [1, 2, 3, 4, 5]

for i in numbers:
    del numbers[0]
    print(i)
# Out:
# 1
# 3
# 5
