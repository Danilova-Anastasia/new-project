# %%
import re
from random import uniform
from collections import defaultdict


r_alphabet = re.compile(u'[а-яА-Я0-9-]+|[.,:;?!]+')

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
def gen_lines(corpus):
    data = open(corpus)
    for line in data:
        yield line.lower()

def gen_tokens(lines):
    for line in lines:
        for token in r_alphabet.findall(line):
            yield token

def gen_trigrams(tokens):
    t0, t1 = '$', '$'
    for t2 in tokens:
        yield t0, t1, t2
        if t2 in '.!?':
            yield t1, t2, '$'
            yield t2, '$','$'
            t0, t1 = '$', '$'
        else:
            t0, t1 = t1, t2

def train(corpus):
    lines = gen_lines(corpus)
    tokens = gen_tokens(lines)
    trigrams = gen_trigrams(tokens)

    bi, tri = defaultdict(lambda: 0.0), defaultdict(lambda: 0.0)

    for t0, t1, t2 in trigrams:
        bi[t0, t1] += 1
        tri[t0, t1, t2] += 1

    model = {}
    for (t0, t1, t2), freq in tri.items():
        if (t0, t1) in model:
            model[t0, t1].append((t2, freq/bi[t0, t1]))
        else:
            model[t0, t1] = [(t2, freq/bi[t0, t1])]
    return model

def generate_sentence(model):
    phrase = ''
    t0, t1 = '$', '$'
    while 1:
        t0, t1 = t1, unirand(model[t0, t1])
        if t1 == '$': 
            break
        if t1 in ('.!?,;:') or t0 == '$':
            phrase += t1
        else:
            phrase += ' ' + t1
    return phrase.capitalize()

def unirand(seq):
    sum_, freq_ = 0, 0
    for item, freq in seq:
        sum_ += freq
    rnd = uniform(0, sum_)
    for token, freq in seq:
        freq_ += freq
        if rnd < freq_:
            return token

# %%
lines = gen_lines('Disgardium_5.txt')

# %%
if __name__ == '__main__':
    model = train('Disgardium_5.txt')
    for i in range(5):
        print(generate_sentence(model))
# Out:
# Разум подсказывал уносить ноги.
# Да не пробудятся спящие!
# Можно было приступать к фарму.
# В доме было уютно, хоть и не выпущу с точки реса, пока ее не было времени.
# Предлагаю вам контракт с кланом.

# %%
model.keys()
# Out:
# dict_keys([('$', '$'), ('$', 'дисгардиум'), ('дисгардиум', '5'), ('5', '.'), ('.', '$'), ('$', 'священная'), ('священная', 'война'), ('война', 'данияр'), ('данияр', 'саматович'), ('саматович', 'сугралинов'), ('сугралинов', 'дисгардиум'), ('5', 'под'), ('под', 'защитой'), ('защитой', 'нергала'), ('нергала', 'лучезарного'), ('лучезарного', 'армии'), ('армии', 'союзников'), ('союзников', 'уверенно'), ('уверенно', 'продвигаются'), ('продвигаются', 'к'), ('к', 'храму'), ('храму', 'тиамат'), ('тиамат', '.'), ('$', 'старые'), ('старые', 'фокусы'), ('фокусы', 'скифа'), ('скифа', 'больше'), ('больше', 'не'), ('не', 'работают'), ('работают', '.'), ('$', 'легат'), ('легат', 'чумного'), ('чумного', 'мора'), ('мора', 'и'), ('и', 'его'), ('его', 'друзья'), ('друзья', 'стоят'), ('стоят', 'перед'), ('перед', 'нелегким'), ('нелегким', 'выбором'), ('выбором', ':'), (':', 'подчиниться'), ('подчиниться', 'пожеланиям'), ('пожеланиям', 'корпорации'), ('корпорации', 'сноусторм'), ('сноусторм', 'и'), ('и', 'выполнить'), ('выполнить', 'задание'), ('задание', 'ядра'), ('ядра', ','), (',', 'сдаться'), ('сдаться', 'превентивам'), ('превентивам', 'или'), ('или', 'отступить'), ('отступить', 'в'), ('в', 'битве'), ('битве', 'за'), ('за', 'храм'), ('храм', 'тиамат'), ('тиамат', ','), (',', 'чтобы'), ('чтобы', 'выиграть'), ('выиграть', 'войну'), ('войну', '?'), ('?', '$'), ('$', 'ясно'), ('ясно', 'одно'), ('одно', ':'), (':', 'без'), ('без', 'союзников'), ('союзников', 'не'), ('не', 'обойтись'), ('обойтись', '.'), ('$', 'ведь'), ('ведь', 'иногда'), ('иногда', 'лучшие'), ('лучшие', 'друзья'), ('друзья', 'получаются'), ('получаются', 'из'), ('из', 'бывших'), ('бывших', 'врагов'), ('врагов', '.'), ('$', 'данияр'), ('данияр', 'сугралинов'), ('5', 'священная'), ('война', 'краткое'), ('краткое', 'содержание'), ('содержание', 'предыдущих'), ('предыдущих', 'книг'), ('книг', 'краткая'), ('краткая', 'история'), ('история', 'будущего'), ('будущего', 'в'), ('в', '2048'), ('2048', 'году'), ('году', 'население'), ('население', 'земли'), ('земли', 'достигло'), ('достигло', 'пятнадцати'), ('пятнадцати', 'миллиардов'), ('миллиардов', '.'), ('$', 'практически'), ('практически', 'всю'), ('всю', 'работу'), ('работу', 'выполняют'), ('выполняют', 'роботы'), ('роботы', '.'), ('$', 'число'), ('число', 'нетрудоспособных'), ('нетрудоспособных', 'людей'), ('людей', 'растет'), ('растет', 'в'), ('в', 'геометрической'), ('геометрической', 'прогрессии'), ('прогрессии', ','), (',', 'они'), ('они', ','), (',', 'будучи'), ('будучи', 'трутнями'), ('трутнями', ','), (',', 'отъедают'), ('отъедают', 'более'), ('более', 'половины'), ('половины', 'мировых'), ('мировых', 'ресурсов'), ('ресурсов', '.'), ('$', 'под'), ('под', 'гнетом'), ('гнетом', 'огромных'), ('огромных', 'подоходных'), ('подоходных', 'налогов'), ('налогов', 'по'), ('по', 'всему'), ('всему', 'миру'), ('миру', 'вспыхивают'), ('вспыхивают', 'бунты'), ('бунты', 'и'), ('и', 'восстания'), ('восстания', ','), (',', 'один'), ('один', 'за'), ('за', 'другим'), ('другим', 'следуют'), ('следуют', 'теракты'), ('теракты', '.'), ('$', 'пророки'), ('пророки', 'и'), ('и', 'предсказатели'), ('предсказатели', 'предвещают'), ('предвещают', 'конец'), ('конец', 'света'), ('света', '.'), ('$', 'часть'), ('часть', 'стран'), ('стран', 'отказывается'), ('отказывается', 'от'), ('от', 'содержания'), ('содержания', 'армии'), ('армии', ','), (',', 'не'), ('не', 'в'), ('в', 'силах'), ('силах', 'прокормить'), ('прокормить', 'собственных'), ('собственных', 'граждан'), ('граждан', '.'), ('$', 'мировые'), ('мировые', 'корпорации'), ('корпорации', 'диктуют'), ('диктуют', 'условия'), ('условия', 'странам'), ('странам', 'и'), ('и', 'регионам'), ('регионам', '.'), ('$', 'бунтующие'), ('бунтующие', 'громят'), ('громят', 'ненавистных'), ('ненавистных', 'эксплуататоров'), ('эксплуататоров', ','), (',', 'но'), ('но', 'остаются'), ('остаются', 'без'), ('без', 'гуманитарной'), ('гуманитарной', 'помощи'), ('помощи', '.'), ('$', 'против'), ('против', 'этих'), ('этих', 'территорий ...

#
# ('чтобы', 'выиграть') [('войну', 0.5), ('время', 0.5)]
#
# (':', 'без') [('союзников', 0.3333333333333333), ('комментариев', 0.6666666666666666)]
#
# ('не', 'обойтись') [('.', 0.75), ('без', 0.25)]
#
# ('$', 'ведь') [('иногда', 0.1), ('все', 0.2), ('так', 0.2), ('скиф', 0.1), ('он', 0.1), ('именно', 0.1), ('за', 0.1), ('мне', 0.1)]
#
# ('$', 'практически') [('всю', 0.5), ('сразу', 0.5)]
#
# ('растет', 'в') [('геометрической', 0.3333333333333333), ('цене', 0.3333333333333333), ('три', 0.3333333333333333)]
#
# (',', 'они') [(',', 0.022727272727272728), ('зависли', 0.022727272727272728), ('уже', 0.06818181818181818), ('рванут', 0.022727272727272728), ('и', 0.045454545454545456), ('существовали', 0.022727272727272728), ('просто', 0.022727272727272728), ('будут', 0.045454545454545456), ('не', 0.045454545454545456), ('вообще', 0.022727272727272728), ('выдавали', 0.022727272727272728), ('все', 0.022727272727272728), ('становятся', 0.022727272727272728), ('стали', 0.022727272727272728), ('планировали', 0.022727272727272728), ('постоянно', 0.022727272727272728), ('забились', 0.022727272727272728), ('исчезали', 0.022727272727272728), ('окутали', 0.022727272727272728), ('рассыпались', 0.022727272727272728), ('что-то', 0.022727272727272728), ('живут', 0.022727272727272728), ('захотят', 0.045454545454545456), ('старательно', 0.022727272727272728), ('грязные', 0.022727272727272728), ('сказали', 0.022727272727272728), ('сдерживали', 0.022727272727272728), ('превысили', 0.022727272727272728), ('там', 0.022727272727272728), ('наполнятся', 0.022727272727272728), ('нуждались', 0.022727272727272728), ('активно', 0.022727272727272728), ('погибли', 0.022727272727272728), ('меня', 0.022727272727272728), ('прекрасно', 0.022727272727272728), ('наносили', 0.022727272727272728), ('рявкнули', 0.022727272727272728), ('больше', 0.022727272727272728)]
#
# ('они', ',') [('будучи', 0.1111111111111111), ('весело', 0.1111111111111111), ('но', 0.1111111111111111), ('как', 0.1111111111111111), ('видимо', 0.1111111111111111), ('хоть', 0.1111111111111111), ('и', 0.1111111111111111), ('погибнув', 0.1111111111111111), ('победившие', 0.1111111111111111)]
#
# (',', 'будучи') [('трутнями', 0.2), ('завербованной', 0.2), ('из', 0.2), ('предвестниками', 0.2), ('неуязвимыми', 0.2)]
#
# ('$', 'под') [('гнетом', 0.08333333333333333), ('утро', 0.08333333333333333), ('чьей', 0.08333333333333333), ('сводами', 0.08333333333333333), ('каждым', 0.08333333333333333), ('деревом', 0.08333333333333333), ('землю', 0.08333333333333333), ('буравящими', 0.08333333333333333), ('бушующие', 0.08333333333333333), ('бафом', 0.08333333333333333), ('проницательным', 0.08333333333333333), ('рукой', 0.08333333333333333)]
#
# ('по', 'всему') [('миру', 0.1), ('полю', 0.1), ('дисгардиуму', 0.1), (',', 0.4), ('списку', 0.1), ('туловищу', 0.1), ('дису', 0.1)]
#
# ('всему', 'миру') [('вспыхивают', 0.5), ('.', 0.5)]
#
# (',', 'один') [('за', 0.3333333333333333), ('из', 0.6666666666666666)]
#
# ('за', 'другим') [('следуют', 0.16666666666666666), ('обычными', 0.16666666666666666), ('в', 0.16666666666666666), ('влил', 0.16666666666666666), ('они', 0.16666666666666666), ('лопнули', 0.16666666666666666)]
#
# ('$', 'часть') [('стран', 0.3333333333333333), ('базовых', 0.3333333333333333), ('ублюдков', 0.3333333333333333)]
#
# ('отказывается', 'от') [('содержания', 0.5), ('комментариев', 0.5)]
#
# ('армии', ',') [('не', 0.5), ('в', 0.5)]
#
# (',', 'не') [('в', 0.03296703296703297), ('имеющими', 0.005494505494505495), ('умирая', 0.005494505494505495), ('воняют', 0.005494505494505495), ('имеющие', 0.005494505494505495), ('защищенного', 0.005494505494505495), ('захламляй', 0.005494505494505495), ('будь', 0.005494505494505495), ('отпуская', 0.005494505494505495), ('принявшие', 0.005494505494505495), ('используя', 0.005494505494505495), ('сводя', 0.016483516483516484), ('было', 0.01098901098901099), ('попавших', 0.005494505494505495), ('спускаясь', 0.005494505494505495), ('специальный', 0.005494505494505495), ('решаясь', 0.01098901098901099), ('знаю', 0.016483516483516484), ('гнушались', 0.005494505494505495), ('смутился', 0.01098901098901099), ('общаюсь', 0.005494505494505495), ('до', 0.01098901098901099), ('одними', 0.005494505494505495), ('удивлюсь', 0.005494505494505495), ('считая', 0.02197802197802198), ('являющихся', 0.005494505494505495), ('вовремя', 0.01098901098901099), ('будет', 0.01098901098901099), ('щадя', 0.01098901098901099), ('видят', 0.005494505494505495), ('новость', 0.005494505494505495), ('меньше', 0.005494505494505495), ('обращая', 0.005494505494505495), ('видели', 0.005494505494505495), ('один', 0.005494505494505495), ('стал', 0.01098901098901099), ('суть', 0.005494505494505495), ('двигаясь', 0.005494505494505495), ('оборачиваясь', 0.005494505494505495), ('открывая', 0.005494505494505495), ('шевельнула', 0.005494505494505495), ('пытаясь', 0.005494505494505495), ('надейся', 0.005494505494505495), ('справиться', 0.005494505494505495), ('жги', 0.005494505494505495), ('чувствуя', 0.01098901098901099), ('теряя', 0.005494505494505495), ('успевает', 0.005494505494505495), ('человек', 0.005494505494505495), ('ной', 0.005494505494505495), ('подверженные', 0.005494505494505495), ('давая', 0.005494505494505495), ('зная', 0.016483516483516484), ('задавая', 0.005494505494505495), ('добившись', 0.01098901098901099), ('приспособлен', 0.005494505494505495), ('затягивай', 0.005494505494505495), ('видя', 0.005494505494505495), ('выяснила', 0.005494505494505495), ('рассказав', 0.005494505494505495), ('раскрывая', 0.005494505494505495), ('от', 0.005494505494505495), ('ври', 0.005494505494505495), ('получив', 0.005494505494505495), ('желающие', 0.005494505494505495), ('существует', 0.005494505494505495), ('дослушав', 0.01098901098901099), ('хочет', 0.005494505494505495), ('успел', 0.005494505494505495), ('эльфу', 0.005494505494505495), ('дворфу', 0.005494505494505495), ('нуждалась', 0.005494505494505495), ('останется', 0.005494505494505495), ('упоминалось', 0.005
#
# ('$', 'отныне') [('блага', 0.3333333333333333), ('они', 0.3333333333333333), ('вы', 0.3333333333333333)]
#
# ('для', 'общества') [('.', 0.3333333333333333), (',', 0.6666666666666666)]
#
# ('только', 'на') [('гражданских', 0.14285714285714285), ('базаре', 0.14285714285714285), ('тех', 0.14285714285714285), ('брюхе', 0.14285714285714285), ('сорок', 0.14285714285714285), ('характеристики', 0.14285714285714285), ('то', 0.14285714285714285)]
#
# ('$', 'неграждане') [('живут', 0.5), ('получают', 0.5)]
#
# ('живут', 'в') [('местах', 0.5), ('зонах', 0.5)]
#
# (',', 'признанных') [('непригодными', 0.5), ('неподходящими', 0.5)]
#
# ('для', 'жизни') [('в', 0.3333333333333333), ('граждан', 0.3333333333333333), ('показатели', 0.3333333333333333)]
#
# ('жизни', 'в') [('силу', 0.16666666666666666), ('бездне', 0.3333333333333333), ('секунду', 0.16666666666666666), ('минуту', 0.16666666666666666), ('сто', 0.16666666666666666)]
#
# ('в', 'силу') [('плохой', 0.5), (',', 0.5)]
#
# ('$', 'с') [('каждым', 0.05194805194805195), ('их', 0.012987012987012988), ('помощью', 0.012987012987012988), ('самого', 0.05194805194805195), ('преувеличенной', 0.012987012987012988), ('разных', 0.012987012987012988), ('расстояния', 0.012987012987012988), ('высоты', 0.012987012987012988), ('грузчиками', 0.012987012987012988), ('девчонкой', 0.012987012987012988), ('тиссой', 0.012987012987012988), ('чего', 0.025974025974025976), ('гордостью', 0.012987012987012988), ('большим', 0.025974025974025976), ('чем', 0.012987012987012988), ('той', 0.012987012987012988), ('жалобным', 0.012987012987012988), ('хрустальным', 0.012987012987012988), ('моей', 0.012987012987012988), ('другой', 0.03896103896103896), ('сомнением', 0.012987012987012988), ('этой', 0.025974025974025976), ('каждой', 0.012987012987012988), ('обещанной', 0.012987012987012988), ('огромной', 0.012987012987012988), ('ноткой', 0.012987012987012988), ('этими', 0.025974025974025976), ('севера', 0.025974025974025976), ('фальшивыми', 0.012987012987012988), ('этого', 0.012987012987012988), ('мелиссой', 0.012987012987012988), ('таким', 0.012987012987012988), ('юных', 0.012987012987012988), ('доставкой', 0.012987012987012988), ('соседней', 0.012987012987012988), ('моего', 0.012987012987012988), ('папиросой', 0.012987012987012988), ('кем', 0.012987012987012988), ('наскока', 0.012987012987012988), ('ними', 0.012987012987012988), ('позволения', 0.012987012987012988), ('паразитом', 0.012987012987012988), ('хрустом', 0.012987012987012988), ('уроном', 0.012987012987012988), ('третьей', 0.012987012987012988), ('удовольствием', 0.012987012987012988), ('какой', 0.012987012987012988), ('лязганьем', 0.012987012987012988), ('утерей', 0.012987012987012988), ('корабля', 0.012987012987012988), ('любопытством', 0.012987012987012988), ('холдеста', 0.012987012987012988), ('днем', 0.012987012987012988), ('дне-е-ем', 0.025974025974025976), ('вероятностью', 0.012987012987012988), ('нарастающим', 0.012987012987012988), ('меня', 0.012987012987012988), ('материалами', 0.012987012987012988), ('просветлевшим', 0.012987012987012988), ('исступленным', 0.012987012987012988), ('выбором', 0.012987012987012988), ('неба', 0.012987012987012988), ('остальным', 0.012987012987012988)]
#
# ('с', 'каждым') [('годом', 0.1), ('уровнем', 0.1), ('договора', 0.1), ('попаданием', 0.1), ('заходом', 0.1), ('убийством', 0.1), ('кланом', 0.1), ('моим', 0.1), ('шагом', 0.1), ('убитым', 0.1)]
#
# ('$', 'даже') [('банальное', 0.041666666666666664), ('логистика', 0.041666666666666664), ('так', 0.041666666666666664), ('нарастающий', 0.041666666666666664), ('патрик', 0.041666666666666664), ('с', 0.041666666666666664), ('ужасная', 0.041666666666666664), ('зрение', 0.041666666666666664), ('если', 0.25), ('сагрившийся', 0.041666666666666664), ('учителя', 0.041666666666666664), ('тогда', 0.041666666666666664), ('несмотря', 0.041666666666666664), ('сборный', 0.041666666666666664), ('магвай', 0.041666666666666664), ('за', 0.041666666666666664), ('не', 0.041666666666666664), ('уравнитель', 0.041666666666666664), ('будучи', 0.041666666666666664)]
#
# ...
#
# ('жнеца', 'и') [('корону', 0.5), ('ударил', 0.5)]
#
# ('корону', 'легата') [('как', 0.3333333333333333), ('и', 0.3333333333333333), ('.', 0.3333333333333333)]
#
# ('под', 'действием') [('агрессивной', 0.5), ('отражения', 0.5)]
#
# ('дождя', ',') [('и', 0.5), ('то', 0.5)]
#
# ('и', 'сквозь') [('кислотные', 0.5), ('брешь', 0.5)]
#
# ('за', 'пределами') [('места', 0.5), ('оазиса', 0.5)]
#
# ('трава', ',') [('то', 0.5), ('во', 0.5)]
#
# ('жвалами', ',') [('напоминающими', 0.25), ('застрекотал', 0.25), ('но', 0.25), ('клешнями', 0.25)]
#
# ('$', 'бараката') [(',', 0.5), ('с', 0.5)]
#
# ('бараката', ',') [('солитоид', 0.25), ('превышающая', 0.25), ('явившаяся', 0.25), ('только', 0.25)]
#
# ('шог', 'рассара') [(',', 0.5), ('.', 0.5)]
#
# ('первый', 'уровень') [(':', 0.5), ('нового', 0.5)]
#
# ('врагов', ',') [('равных', 0.5), ('но', 0.5)]
#
# ('вероятностью', '1') [('сохраните', 0.5), ('вы', 0.5)]
#
# ('$', 'таракан') [('повел', 0.5), ('помог', 0.5)]
#
# (',', 'подвигал') [('жвалами', 0.5), ('шеей', 0.5)]
#
# ('баракат', ',') [('угрожающе', 0.25), ('пока', 0.25), ('повисших', 0.25), ('не', 0.25)]
#
# ('выбив', 'из') [('таракана', 0.5), ('осаждающих', 0.5)]
#
# ('мои', 'кости') [('.', 0.5), ('почернели', 0.5)]
#
# ('распалась', 'на') [('две', 0.3333333333333333), ('десятку', 0.3333333333333333), ('фрагменты', 0.3333333333333333)]
#
# ('в', 'мою') [('пользу', 0.25), ('команду', 0.25), ('рейдовую', 0.25), ('сторону', 0.25)]
#
# ('из', 'отверстий') [('сита', 0.5), (',', 0.5)]
#
# ('из', 'йорубы') [(',', 0.16666666666666666), ('по', 0.16666666666666666), ('к', 0.16666666666666666), ('до', 0.16666666666666666), ('.', 0.16666666666666666), ('накинул', 0.16666666666666666)]
#
# ('один', 'вопрос') [('.', 0.5), (':', 0.5)]
#
# ('и', 'культистов') [('морены', 0.3333333333333333), ('.', 0.3333333333333333), (',', 0.3333333333333333)]
#
# ('защиту', 'храма') [('спящей', 0.25), ('многомудрой', 0.25), ('.', 0.25), (',', 0.25)]
#
# ('я', 'им') [('отказал', 0.5), ('займусь', 0.5)]
#
# ('битве', ',') [('но', 0.3333333333333333), ('колдун', 0.3333333333333333), ('пока', 0.3333333333333333)]
#
# ('и', 'бомбовоза') [('стали', 0.5), ('.', 0.5)]
#
# ('вопрос', ':') [('как', 0.5), ('да', 0.5)]
#
# ('когда', 'тиамат') [('нас', 0.5), ('влила', 0.5)]
#
# ('флейгрей', 'и') [('нега', 0.5), ('спросил', 0.5)]
#
# ('фоне', 'светлеющего') [('неба', 0.5), ('горизонта', 0.5)]
#
# ('вообще-то', ',') [('мы', 0.5), ('досталось', 0.5)]
#
# ('хотя', 'для') [('меня', 0.5), ('неграждан', 0.5)]
#
# ('на', 'всеобщем') [('?', 0.5), (',', 0.5)]
#
# ('$', 'пустыня') [(',', 0.5), ('зазеленела', 0.5)]
#
# ('пытались', 'пробиться') [('внутрь', 0.5), ('хорвац', 0.5)]
#
# ('бывший', 'зверобог') [('недобро', 0.5), ('стерпел', 0.5)]
#
# ('храм', 'с') [('друзьями', 0.5), ('северной', 0.5)]
#
# ('со', 'спящей') [('.', 0.5), ('богиней', 0.5)]
#
# ('$', 'удачи') [(',', 0.5), ('.', 0.5)]
#
# ('богиня', ',') [('больше', 0.5), ('я', 0.5)]
#
# ('божественная', 'способность') [('правосудие', 0.25), ('содействие', 0.25), ('.', 0.5)]
#
# ('правосудие', 'спящих') [(';', 0.25), ('2-го', 0.25), (':', 0.25), ('среагировало', 0.25)]
#
# ('опыта', 'на') [('текущем', 0.6666666666666666), ('10', 0.3333333333333333)]
#
# ('281', ',') [('34', 0.5), ('69', 0.5)]
#
# ('репутация', 'со') [('спящей', 0.2), ('спящим', 0.8)]
#
# ('спящим', 'богом') [('бегемотом', 0.25), ('кингу', 0.25), ('абзу', 0.25), ('левиафаном', 0.25)]
#
# ('$', 'правосудие') [('спящих', 0.75), ('напомнило', 0.25)]
#
# ('уровень', 'способности') [('всегда', 0.5), ('.', 0.5)]
#
# ('объем', 'возмездия') [('повышаются', 0.5), (',', 0.5)]
#
# ('за', 'каждый') [('уровень', 0.6666666666666666), ('новый', 0.3333333333333333)]
#
# ('потенциала', 'осталось') [('четыре', 0.5), ('?', 0.5)]
#
# ('я', 'получу') [('за', 0.5), ('пятнадцать', 0.5)]
#
# ('и', 'способности') [(',', 0.5), (':', 0.5)]
#
# ('напомнило', 'мне') [('талант', 0.5), ('о', 0.5)]
#
# ('содействия', ',') [('то', 0.5), ('но', 0.5)]
#
# ('на', '40') [('.', 0.5), (',', 0.5)]
#
# ('все', 'стороны') [(',', 0.5), ('разбежались', 0.5)]
#
# ('силу', 'только') [('тогда', 0.5), ('по', 0.5)]
#
# ('друзья', 'тоже') [('не', 0.5), ('с', 0.5)]
#
# ('это', 'случится') [('снова', 0.5), ('на', 0.5)]
#
# ('без', 'защиты') [('.', 0.5), ('пожертвования', 0.5)]
#
# ('ты', 'снова') [('станешь', 0.5), ('живой', 0.5)]
#
# ('своих', 'последователей') [('я', 0.5), ('.', 0.5)]
#
# ('храм', 'будет') [('окружен', 0.5), ('поглощен', 0.5)]
#
# ('стояли', 'в') [('центре', 0.5), ('окружении', 0.5)]
#
# ('$', 'бабангида') [('и', 0.5), ('осознал', 0.5)]
#
# ('ответил', 'йеми') [('.', 0.6666666666666666), (',', 0.3333333333333333)]
#
# ('твои', 'друзья') [('не', 0.5), ('настоящие', 0.5)]
#
# ('армией', 'нергала') [(',', 0.5), ('.', 0.5)]
#
# ('$', 'орки') [('клана', 0.5), ('сломанного', 0.5)]
#
# ('улыбнулся', ',') [('представив', 0.5), ('вытащил', 0.5)]
#
# ('представив', ',') [('как', 0.5), ('какое', 0.5)]
#
# (',', 'сарронос') [('видит', 0.5), (',', 0.5)]
#
# ('сарронос', ',') [('в', 0.5), ('орк', 0.5)]
#
# ('воинов', 'на') [('защиту', 0.5), ('передовую', 0.5)]
#
# ('многомудрой', 'тиамат') [(',', 0.5), ('.', 0.5)]
#
# ('монетку', 'кусаларикс') [('.', 0.5), ('и', 0.5)]
#
# ('в', 'пространстве') [('разрослась', 0.3333333333333333), (',', 0.3333333333333333), ('вывалились', 0.3333333333333333)]
#
# ('$', 'хм') [('дам', 0.5), ('с', 0.5)]
#
# ('кого', 'ты') [('называешь', 0.5), ('согласишься', 0.5)]
#
# ('$', 'этих') [('двух', 0.5), ('ребят', 0.5)]
#
# ('грудь', 'и') [('провозгласил', 0.3333333333333333), ('вырвал', 0.3333333333333333), ('кричал', 0.3333333333333333)]
#
# ('кусаларикс', 'и') [('снова', 0.5), ('проговорил', 0.5)]
#
# ('мне', 'нужны') [('не', 0.5), ('все', 0.5)]
#
# ('ссы', ',') [('салага', 0.5), ('бро', 0.5)]
#
# ('раскрылся', 'портал') [('.', 0.5), (',', 0.5)]
#
# ('наемников', 'и') [('лучших', 0.5), ('гладиаторов', 0.5)]
#
# ('гладиаторов', 'арены') [('на', 0.5), ('.', 0.5)]
#
# ('это', 'несложно') [(',', 0.5), ('.', 0.5)]
#
# ('от', 'одного') [('армагеддона', 0.5), ('его', 0.5)]
#
# ('$', 'моему') [('клану', 0.5), ('взору', 0.5)]
#
# ('с', 'материалами') [('тоже', 0.5), ('.', 0.5)]
#
# ('когда', 'на') [('нее', 0.5), ('хинтерлиста', 0.5)]
#
# ('восьми', 'тысяч') [('очков', 0.5), ('последователей', 0.5)]
#
# ('в', 'росте') [('и', 0.5), ('.', 0.5)]
#
# ('огр', 'бабангида') [('без', 0.3333333333333333), (',', 0.3333333333333333), ('к', 0.3333333333333333)]
#
# ('бабангида', 'без') [('проблем', 0.5), ('устали', 0.5)]
#
# (',', 'выпил') [('несколько', 0.5), ('кофе', 0.5)]
#
# ('интерфейс', ',') [('убедился', 0.5), ('я', 0.5)]
#
# ('нас', 'нет') [(',', 0.5), ('.', 0.5)]
#
# ('прямо', 'здесь') [(',', 0.5), ('.', 0.5)]
#
# ('кислотный', 'дождь') [('голоса', 0.5), ('быстро', 0.5)]
#
# ('неуязвимость', 'спящих') [('.', 0.25), (':', 0.25), ('поглощала', 0.25), ('я', 0.25)]
#
# ('идет', 'по') [('плану', 0.5), ('рейду', 0.5)]
#
# ('я', 'пролетел') [('по', 0.5), ('через', 0.5)]
#
# ('ног', ',') [('и', 0.3333333333333333), ('а', 0.3333333333333333), ('но', 0.3333333333333333)]
#
# ('агро', 'на') [('себе', 0.5), ('кого', 0.5)]
#
# ('не', 'убить') [('патрика', 0.5), ('!', 0.5)]
#
# ('бабангида', ',') [('размахивая', 0.5), ('франциска', 0.5)]
#
# (',', 'фамильяры') [('колдуна', 0.5), ('игнорировали', 0.5)]
#
# ('штрафы', 'на') [('разницу', 0.5), ('урон', 0.5)]
#
# ('оставалось', ',') [('это', 0.5), ('так', 0.5)]
#
# (',', 'урон') [('я', 0.5), (',', 0.5)]
#
# ('на', 'их') [('начертание', 0.5), ('улыбающиеся', 0.5)]
#
# ('поглощающая', 'плоть') [(',', 0.7142857142857143), ('лишь', 0.14285714285714285), ('древняя', 0.14285714285714285)]
#
# ('матерая', 'далезма') [(',', 0.5), ('!', 0.25), ('.', 0.25)]
#
# ('далезма', ',') [('солитоид', 0.5), ('мертва', 0.5)]
#
# (',', 'пробив') [('во', 0.5), ('дыру', 0.5)]
#
# ('$', 'взревел') [('бабангида', 0.5), ('магвай', 0.5)]
#
# ('ложноножку', ',') [('которая', 0.3333333333333333), ('ее', 0.3333333333333333), ('но', 0.3333333333333333)]
#
# ('в', 'желе') [('концентрация', 0.5), ('.', 0.5)]
#
# ('желе', ',') [('в', 0.5), ('как', 0.5)]
#
# ('яростью', ',') [('и', 0.5), ('но', 0.5)]
#
# ('зелья', 'здоровья') [('.', 0.5), (',', 0.5)]
#
# ('небо', ',') [('на', 0.5), ('слепящее', 0.5)]
#
# ('я', 'использовал') [('все', 0.5), ('его', 0.5)]
#
# ('способности', ':') [('жуткий', 0.3333333333333333), ('глубинная', 0.3333333333333333), ('возмездие', 0.3333333333333333)]
#
# ('ушла', 'в') [('пустоту', 0.5), ('красную', 0.5)]
#
# ('освобождение', 'не') [('работало', 0.5), ('отдало', 0.5)]
#
# ('вне', 'боя') [(',', 0.5), ('они', 0.5)]
#
# ('метнул', 'в') [('спину', 0.5), ('босса', 0.5)]
#
# ('но', 'этим') [('все', 0.5), ('лишь', 0.5)]
#
# ('в', 'босса') [('по', 0.5), ('упрочненный', 0.5)]
#
# ('трезубец', 'громовержец') [('с', 0.5), (',', 0.5)]
#
# ('$', 'издали') [('раздавались', 0.5), ('раздался', 0.5)]
#
# ('но', 'без') [('растворившихся', 0.3333333333333333), ('них', 0.3333333333333333), ('подробностей', 0.3333333333333333)]
#
# ('яйцо', 'далезмы') [('.', 0.5), ('легендарный', 0.5)]
#
# ('солитоидов', ',') [('невосприимчивый', 0.5), ('которая', 0.5)]
#
# ('не', 'без') [('участия', 0.5), ('сарказма', 0.5)]
#
# ('гроза', 'солитоидов') [('вы', 0.5), ('.', 0.5)]
#
# ('$', 'бонус') [('в', 0.1111111111111111), ('к', 0.8888888888888888)]
#
# ('и', 'пожертвования') [('могла', 0.5), (':', 0.5)]
#
# ('группе', ',') [('йеми', 0.5), ('снова', 0.5)]
#
# ('сделаю', 'это') [('не', 0.5), ('во', 0.5)]
#
# ('и', 'орки') [('сломанного', 0.5), (',', 0.5)]
#
# ('проверю', ',') [('как', 0.5), ('что', 0.5)]
#
# ('вокруг', 'храма') [('превратилась', 0.3333333333333333), ('сжималось', 0.3333333333333333), ('сжимались', 0.3333333333333333)]
#
# ('над', 'храмом') [('темнели', 0.3333333333333333), (',', 0.6666666666666666)]
#
# ('в', 'землю') [('золотой', 0.5), ('.', 0.5)]
#
# ('начали', 'выходить') [('работяги', 0.3333333333333333), ('орки', 0.3333333333333333), ('кобольды-зомби', 0.3333333333333333)]
#
# ('приблизился', 'и') [('поприветствовал', 0.5), ('начал', 0.5)]
#
# ('жреца', 'нергала') [('во', 0.3333333333333333), ('в', 0.3333333333333333), ('.', 0.3333333333333333)]
#
# ('собрались', 'все') [('наши', 0.5), (',', 0.5)]
#
# ('топора', 'и') [('сейчас', 0.25), ('бойцы', 0.25), ('культисты', 0.25), ('велел', 0.25)]
#
# ('$', 'спящая') [('исчезла', 0.3333333333333333), ('указала', 0.3333333333333333), ('не', 0.3333333333333333)]
#
# ('через', 'мгновение') [('с', 0.5), ('она', 0.5)]
#
# ('навык', 'чумное') [('поветрие', 0.5), ('усиление', 0.5)]
#
# (',', 'эльфы') [('и', 0.5), ('джошуа', 0.5)]
#
# ('не', 'такое') [('видали', 0.5), ('могучее', 0.5)]
#
# ('и', 'гладиаторы') [('пошли', 0.3333333333333333), (',', 0.6666666666666666)]
#
# ('живым', ',') [('а', 0.5), ('ты', 0.5)]
#
# ('подземный', 'ужастень') [('783-го', 0.5), ('.', 0.25), ('акулон', 0.25)]
#
# ('783-го', 'уровня') [(',', 0.5), ('.', 0.5)]
#
# ('крушитель', ',') [('свирепый', 0.6666666666666666), ('видимо', 0.3333333333333333)]
#
# ('30-го', 'уровня') [(',', 0.5), ('.', 0.5)]
#
# ('гладиаторы', ',') [('присланные', 0.5), ('развернув', 0.5)]
#
# ('они', 'идут') [('на', 0.5), ('сюда', 0.5)]
#
# ('рейд', 'и') [('взять', 0.3333333333333333), ('протараторил', 0.3333333333333333), ('прибереженные', 0.3333333333333333)]
#
# ('битве', 'не') [('было', 0.5), ('зазорно', 0.5)]
#
# (',', 'величайший') [('каратель', 0.5), ('мститель', 0.5)]
#
# ('величайший', 'каратель') [(',', 0.25), ('.', 0.75)]
#
# ('величайший', 'мститель') [(',', 0.25), ('.', 0.75)]
#
# ('юный', 'гладиатор') [('все', 0.5), ('.', 0.5)]
#
# (':', '16') [('лет', 0.5), ('.', 0.5)]
#
# ('бонус', 'к') [('дистанционному', 0.125), ('критическому', 0.125), ('силе', 0.125), ('скорости', 0.125), ('шансу', 0.5)]
#
# ('урону', ':') [('649', 0.5), ('1', 0.5)]
#
# ('к', 'шансу') [('оглушить', 0.25), ('получить', 0.5), ('уклонения', 0.25)]
#
# ('шансу', 'получить') [('улучшенную', 0.5), ('уникальный', 0.5)]
#
# (':', '18') [('?', 0.5), ('.', 0.5)]
#
# ('навыки', ':') [('безоружный', 0.5), ('божественное', 0.5)]
#
# ('ранга', ':') [('27', 0.2), ('36', 0.1), ('48', 0.1), ('12', 0.1), ('66', 0.1), ('83', 0.1), ('57', 0.1), ('69', 0.1), ('4', 0.1)]
#
# (':', 'величайший') [('каратель', 0.5), ('мститель', 0.5)]
#
# ('$', 'освобождение') [(':', 0.5), ('не', 0.5)]
#
# ('$', 'божественные') [('способности', 0.5), ('знаки', 0.5)]
#
# ('$', 'величайший') [('каратель', 0.5), ('мститель', 0.5)]
#
# ('мага', ':') [('путь', 0.5), ('довольно', 0.5)]
#
# (',', 'боевые') [('спутники', 0.5), ('питомцы', 0.5)]
#
# ('статус', ':') [('угроза', 0.5), ('инициал', 0.5)]
#
# ('храмом', ',') [('чтобы', 0.5), ('окруженным', 0.5)]
#
# ('с', 'юга') [('.', 0.5), ('уверенно', 0.5)]
#
# ('бога', 'тьмы') [('смотрелась', 0.5), ('.', 0.5)]
#
# ('в', 'авангарде') [('противника', 0.5), ('собрались', 0.5)]
#
# ('катапульты', ',') [('миниатюрные', 0.5), ('посылая', 0.5)]
#
# ('аспекты', 'света') [(',', 0.8), ('.', 0.2)]
#
# ('уровней', 'выше') [('самого', 0.5), ('меня', 0.25), (',', 0.25)]
#
# ('и', 'мардук') [('не', 0.25), ('одарили', 0.25), ('смеялись', 0.25), ('.', 0.25)]
#
# ('$', 'мардук') [('чуть', 0.5), (',', 0.5)]
#
# ('$', 'колоссы') [('тьмы', 0.5), ('и', 0.5)]
#
# ('колоссы', 'тьмы') [('были', 0.5), ('и', 0.5)]
#
# ('и', 'аспекты') [('света', 0.75), ('развоплотятся', 0.25)]
#
# ('жрецами', 'мардука') [('.', 0.5), (',', 0.5)]
#
# ('альянса', ':') [('странники', 0.5), ('гном', 0.5)]
#
# ('над', 'ними') [('развевались', 0.3333333333333333), ('высился', 0.3333333333333333), ('нависал', 0.3333333333333333)]
#
# ('без', 'сомнений') [(',', 0.5), ('.', 0.5)]
#
# ('мои', 'союзники') [('заняли', 0.5), ('тоже', 0.5)]
#
# ('аватар', 'тиамат') [('и', 0.5), (',', 0.5)]
#
# ('к', 'троггам') [('.', 0.5), ('и', 0.5)]
#
# ('декотра', 'и') [('полуорк', 0.5), ('ранакоц', 0.5)]
#
# (',', 'полуорк') [('побежал', 0.5), ('получил', 0.5)]
#
# (',', 'грозу') [('и', 0.5), (',', 0.5)]
#
# ('и', 'акулона') [('в', 0.5), ('.', 0.5)]
#
# ('ними', ',') [('не', 0.5), ('треща', 0.5)]
#
# ('до', 'орков') [('сломанного', 0.5), ('клана', 0.5)]
#
# ('в', 'рейд') [('и', 0.5), (',', 0.5)]
#
# ('нарушил', 'тишину') [('кто-то', 0.5), (',', 0.5)]
#
# ('урон', 'по') [('мне', 0.5), ('зданиям', 0.5)]
#
# ('продолжал', 'получать') [('повреждения', 0.5), ('урон', 0.5)]
#
# ('но', 'мои') [('упражнения', 0.5), ('усилия', 0.5)]
#
# ('по', 'храму') [(':', 0.3333333333333333), ('и', 0.3333333333333333), ('гигант', 0.3333333333333333)]
#
# ('наступавших', ',') [('а', 0.5), ('я', 0.5)]
#
# ('прочность', 'строения') [('показывала', 0.5), ('то', 0.5)]
#
# ('трогги', ',') [('орки', 0.5), ('стражи', 0.5)]
#
# ('моя', 'жизнь') [('рухнула', 0.5), ('ушла', 0.5)]
#
# ('займусь', 'превентивами') [('!', 0.5), ('.', 0.5)]
#
# ('где', 'они') [('дрались', 0.5), ('?', 0.5)]
#
# ('храм', 'не') [('выдержит', 0.5), ('отстоять', 0.5)]
#
# ('со', 'жрецами') [(',', 0.5), ('мардука', 0.5)]
#
# ('не', 'положить') [('товарищей', 0.5), ('весь', 0.5)]
#
# ('сработало', ',') [('а', 0.5), ('орки', 0.5)]
#
# ('щиты', 'и') [('силовые', 0.5), ('ауру', 0.5)]
#
# ('человек', 'в') [('модусе', 0.5), ('стелс-костюме', 0.5)]
#
# ('и', 'ударил') [('следом', 0.5), ('его', 0.5)]
#
# ('аспектов', 'света') [('выстрелили', 0.5), ('перестали', 0.5)]
#
# ('и', 'царапины') [('.', 0.5), ('имитация', 0.5)]
#
# ('сияния', ',') [('ауры', 0.5), ('оказалась', 0.5)]
#
# ('хватило', 'одного') [('комбо', 0.5), ('удара', 0.5)]
#
# ('чтобы', 'нергал') [('остался', 0.5), ('не', 0.5)]
#
# ('воздухе', 'и') [('аспекты', 0.5), ('замерцал', 0.5)]
#
# ('по', 'лицу') [('кровь', 0.5), (',', 0.5)]
#
# ('жрецов', 'нергала') [('.', 0.5), (',', 0.5)]
#
# ('верховному', 'жрецу') [('мардука', 0.5), ('бога', 0.5)]
#
# (',', 'прозвучал') [('из', 0.5), ('сверху', 0.5)]
#
# ('ним', 'в') [('обнимку', 0.5), ('бывший', 0.5)]
#
# ('вытащил', 'из') [('ниоткуда', 0.5), ('песка', 0.5)]
#
# ('ребра', ',') [('вырывая', 0.5), ('орки', 0.5)]
#
# ('$', 'барьер') [('или', 0.5), ('пал', 0.5)]
#
# ('спайка', 'душ') [(',', 0.3333333333333333), ('запнулась', 0.3333333333333333), ('распалась', 0.3333333333333333)]
#
# ('весь', 'рейд') [('своей', 0.5), ('йорубы', 0.5)]
#
# ('на', 'хинтерлиста') [('налетело', 0.5), ('обрушился', 0.5)]
#
# ('из', 'наших') [('союзников', 0.5), (',', 0.5)]
#
# ('нергал', 'не') [('одобрит', 0.5), ('возбудился', 0.5)]
#
# ('чтобы', 'начать') [('немедленно', 0.5), ('его', 0.5)]
#
# ('бывший', 'легат') [(',', 0.5), ('чумного', 0.5)]
#
# ('вместо', 'меня') [('магвая', 0.5), ('йеми', 0.5)]
#
# ('$', 'картинка') [('распалась', 0.5), ('показывала', 0.5)]
#
# ('бывший', 'замок') [('вдоводелов', 0.5), ('?', 0.5)]
#
# ('видео', 'с') [('камер', 0.5), ('отворачивающейся', 0.5)]
#
# ('эту', 'хрень') [('!', 0.5), ('надо', 0.5)]
#
# (':', 'эльф') [('и', 0.5), ('был', 0.5)]
#
# ('клана', 'элита') [(',', 0.5), ('и', 0.5)]
#
# ('$', 'довольна') [('?', 0.5), ('.', 0.5)]
